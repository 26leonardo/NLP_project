# %% [markdown]
# # Assignment 2
#
# **Credits**: Federico Ruggeri, Eleonora Mancini, Paolo Torroni
#
# **Keywords**: Sexism Detection, Multi-class Classification, LLMs, Prompting

# %% [markdown]
# # Contact
#
# For any doubt, question, issue or help, you can always contact us at the following email addresses:
#
# Teaching Assistants:
#
# * Federico Ruggeri -> federico.ruggeri6@unibo.it
# * Eleonora Mancini -> e.mancini@unibo.it
#
# Professor:
#
# * Paolo Torroni -> p.torroni@unibo.it

# %% [markdown]
# # Relevant Material
#
# - Tutorial 3
# - Huggingface documentation
# - Huggingface hub

# %% [markdown]
# # Introduction
#
# You are tasked to address the [EDOS Task B](https://github.com/rewire-online/edos) on sexism detection.

# %% [markdown]
# ## Problem definition
#
# Given an input text sentence, the task is to label the sentence as not-sexist or one of these four sexist categories: (1) threats, (2)  derogation, (3) animosity, (4) prejudiced discussion.
#
# ### Examples:
#
# **Text**: *``Schedule a date with her, then don't show up. Then text her "GOTCHA B___H".''*
#
# **Label**: Threats
#
# **Text**: *``That’s completely ridiculous a woman flashing her boobs is not sexual assault in the slightest.''*
#
# **Label**: Not sexist

# %% [markdown]
# ## Approach
#
# We will tackle the five-class classification task with LLMs.
#
# In particular, we'll consider zero-/few-shot prompting approaches to assess the capability of some popular open-source LLMs on this task.

# %% [markdown]
# ## Preliminaries
#
# We are going to download LLMs from [Huggingface](https://huggingface.co/).
#
# Many of these open-source LLMs require you to accept their "Community License Agreement" to download them.
#
# In summary:
#
# - If not already, create an account of Huggingface (~2 mins)
# - Check a LLM model card page (e.g., [Mistral v3](https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3)) and accept its "Community License Agreement".
# - Go to your account -> Settings -> Access Tokens -> Create new token -> "Repositories permissions" -> add the LLM model card you want to use.
# - Save the token (we'll need it later)

# %% [markdown]
# ### Huggingface Login
#
# Once we have created an account and an access token, we need to login to Huggingface via code.
#
# - Type your token and press Enter
# - You can say No to Github linking

# %%
# PIPs
! pip install -U bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.9.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Downloading bitsandbytes-0.49.0-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 13.4 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.0

# %%
# NOTE: run it on colab
# pelle: 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
# !hf auth login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: read).
# The token `HF_TOKEN` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `HF_TOKEN`

# %% [markdown]
# After login, you can download all models associated with your access token in addition to those that are not protected by an access token.

# %% [markdown]
# ### Data Loading
#
# Since we are only interested in prompting, we do not require a train dataset.
#
# We have preparared a small test set version of EDOS in our dedicated [Github repository](https://github.com/lt-nlp-lab-unibo/nlp-course-material).
#
# Check the ``Assignment 2/data`` folder.
# It contains:
#
# - ``a2_test.csv`` → a small test set of 300 samples.
# - ``demonstrations.csv`` -> a batch of 1000 samples for few-shot prompting.
#
# Both datasets contain a balanced number of sexist and not sexist samples.

# %% [markdown]
# ### Instructions
#
# We require you to:
#
# * **Download** the ``A2/data`` folder.
# * **Encode** ``a2_test.csv`` into a ``pandas.DataFrame`` object.

# %%
# IMPORTS
import pandas as pd
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
! rm -rf nlp-course-material
! git clone https://github.com/nlp-unibo/nlp-course-material.git
# Out:
# Cloning into 'nlp-course-material'...
# remote: Enumerating objects: 424, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 424 (delta 0), reused 2 (delta 0), pack-reused 418 (from 1)
# Receiving objects: 100% (424/424), 8.83 MiB | 19.96 MiB/s, done.
# Resolving deltas: 100% (190/190), done.

# %%
data_path = "./nlp-course-material/2025-2026/Assignment 2/data/"
test_df = pd.read_csv(data_path + "a2_test.csv")

# %% [markdown]
# # [Task 1 - 0.5 points] Model setup
#
# Once the test data has been loaded, we have to setup the model pipeline for inference.
#
# In particular, we have to:
# - Load the model weights from Huggingface
# - Quantize the model to fit into a single-GPU limited hardware

# %% [markdown]
# ## Which LLMs?
#
# The pool of LLMs is ever increasing and it's impossible to keep track of all new entries.
#
# We focus on popular open-source models.
#
# - [Mistral v2](https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2)
# - [Mistral v3](https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3)
# - [Llama v3.1](https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct)
# - [Phi3-mini](https://huggingface.co/microsoft/Phi-3-mini-4k-instruct)
# - [TinyLlama](https://huggingface.co/TinyLlama/TinyLlama-1.1B-Chat-v1.0)
# - [DeepSeek-R1](https://huggingface.co/deepseek-ai/DeepSeek-R1-Distill-Qwen-7B)
# - [Qwen3](https://huggingface.co/Qwen/Qwen3-1.7B)
#
# Other open-source models are more than welcome!

# %% [markdown]
# ### Instructions
#
# In order to get Task 1 points, we require you to:
#
# * Pick 2 model cards from the provided list.
# * For each model:
#   - Setup a quantization configuration for the model.
#   - Load the model via HuggingFace APIs.

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import torch
import os

def setup_model(card_name, local_path="drive/MyDrive/models/"):

    model_path = local_path + card_name.replace("/", "_")

    if not os.path.exists(local_path) : os.makedirs(local_path)
    if not os.path.exists(model_path):
        tokenizer = AutoTokenizer.from_pretrained(card_name)
        tokenizer.pad_token = tokenizer.eos_token

        model_bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_use_double_quant=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.bfloat16
        )

        model = AutoModelForCausalLM.from_pretrained(
            card_name,
            return_dict=True,
            quantization_config=model_bnb_config,
            device_map='auto',
            dtype=torch.bfloat16
        )

        model.save_pretrained(model_path)
        tokenizer.save_pretrained(model_path)

    else:
        tokenizer = AutoTokenizer.from_pretrained(model_path)
        tokenizer.pad_token = tokenizer.eos_token

        model = AutoModelForCausalLM.from_pretrained(
            model_path,
            return_dict=True,
            device_map='auto',
            dtype=torch.bfloat16
        )

    model_gen_config = model.generation_config
    model_gen_config.max_new_tokens = 100
    model_gen_config.eos_token_id = tokenizer.eos_token_id
    model_gen_config.pad_token_id = tokenizer.eos_token_id
    model_gen_config.temperature = None
    model_gen_config.num_return_sequences = 1

    return model, tokenizer

# %%
mistral_card = "mistralai/Mistral-7B-Instruct-v0.3"
qwen_card = "Qwen/Qwen3-1.7B"

print("Loading Mistral-3...")
mistral_model, mistral_tokenizer = setup_model(mistral_card)
print("Loading Qwen3")
qwen_model, qwen_tokenizer = setup_model(qwen_card)

models = {
    "mistral": {
        "card": mistral_card,
        "model": mistral_model,
        "tokenizer": mistral_tokenizer
    },
    "qwen": {
        "card": qwen_card,
        "model": qwen_model,
        "tokenizer": qwen_tokenizer
    }
}
# Out:
# Loading Mistral-3...
# Loading Qwen3
# The tokenizer you are loading from 'drive/MyDrive/models/Qwen_Qwen3-1.7B' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.

# %% [markdown]
# ### Note
#
# There's a popular library integrated with Huggingface's ``transformers`` to perform quantization.

# %% [markdown]
# # [Task 2 - 1.0 points] Prompt setup
#
# Prompting requires an input pre-processing phase where we convert each input example into a specific instruction prompt.

# %% [markdown]
# ## Prompt Template
#
# Use the following prompt template to process input texts.

# %%
prompt = [
    {
        'role': 'system',
        'content': 'You are an annotator for sexism detection.'
    },
    {
        'role': 'user',
        'content': """Your task is to classify input text as not-sexist
         or sexist. If sexist, classify input text according to one
         of the following four categories: threats, derogation,
         animosity, prejudiced discussion.

         Below you find sexist categories definitions:
         Threats: the text expresses intent or desire to harm a woman.
         Derogation: the text describes a woman in a derogative manner.
         Animosity: the text contains slurs or insults towards a woman.
         Prejudiced discussion: the text expresses supports for
         mistreatment of women as individuals.

         Respond only by writing one of the following categories:
         not-sexist, threats, derogation, animosity, prejudiced.

        TEXT: {text}

        ANSWER:
        """
    }
]

# %%
# DEBUG
for name, model in models.items():
  print(f"Model: {name}")
  formatted_prompt = model["tokenizer"].apply_chat_template(
      prompt,
      tokenize=False,
      add_generation_prompt=True
  )
  print(formatted_prompt)
  print("*"*50)
# Out:
# Model: mistral
# <s>[INST] You are an annotator for sexism detection.
#
# Your task is to classify input text as not-sexist
#          or sexist. If sexist, classify input text according to one
#          of the following four categories: threats, derogation,
#          animosity, prejudiced discussion.
#
#          Below you find sexist categories definitions:
#          Threats: the text expresses intent or desire to harm a woman.
#          Derogation: the text describes a woman in a derogative manner.
#          Animosity: the text contains slurs or insults towards a woman.
#          Prejudiced discussion: the text expresses supports for
#          mistreatment of women as individuals.
#
#          Respond only by writing one of the following categories:
#          not-sexist, threats, derogation, animosity, prejudiced.
#
#         TEXT: {text}
#
#         ANSWER:
#         [/INST]
# **************************************************
# Model: qwen
# <|im_start|>system
# You are an annotator for sexism detection.<|im_end|>
# <|im_start|>user
# Your task is to classify input text as not-sexist
#          or sexist. If sexist, classify input text according to one
#          of the following four categories: threats, derogation,
#          animosity, prejudiced discussion.
#
#          Below you find sexist categories definitions:
#          Threats: the text expresses intent or desire to harm a woman.
#          Derogation: the text describes a woman in a derogative manner.
#          Animosity: the text contains slurs or insults towards a woman.
#          Prejudiced discussion: the text expresses supports for
#          mistreatment of women as individuals.
#
#          Respond only by writing one of the following categories:
#          not-sexist, threats, derogation, animosity, prejudiced.
#
#         TEXT: {text}
#
#         ANSWER:
#         <|im_end|>
# <|im_start|>assistant
#
# **************************************************

# %% [markdown]
# ### Instructions
#
# In order to get Task 2 points, we require you to:
#
# * Write a ``prepare_prompts`` function as the one reported below.

# %%
def prepare_prompts(texts, prompt_template, tokenizer):
  """
    This function format input text samples into instructions prompts.

    Inputs:
      texts: input texts to classify via prompting
      prompt_template: the prompt template provided in this assignment
      tokenizer: the transformers Tokenizer object instance associated
      with the chosen model card

    Outputs:
      input texts to classify in the form of instruction prompts
  """
  # Make the single message as chat
  prompt_template_chat = tokenizer.apply_chat_template(
      prompt_template, tokenize=False, add_generation_prompt=True
  )
  # Substitue the text placeholder with the text
  formatted_prompts_chat = [prompt_template_chat.format(text = text) for text in texts]

  # Tokenize the formatted chat for the model
  tokenized_prompts_chat = tokenizer(
      formatted_prompts_chat, padding=True,
      return_tensors='pt'
  ).to('cuda')

  return tokenized_prompts_chat

# %% [markdown]
# ### Notes
#
# 1. You are free to modify the prompt format (**not its content**) as you like depending on your code implementation.
#
# 2. Note that the provided prompt has placeholders. You need to format the string to replace placeholders. Huggingface might have dedicated APIs for this.

# %% [markdown]
# # [Task 3 - 1.0 points] Inference
#
# We are now ready to define the inference loop where we prompt the model with each pre-processed sample.

# %% [markdown]
# ### Instructions
#
# In order to get Task 3 points, we require you to:
#
# * Write a ``generate_responses`` function as the one reported below.
# * Write a ``process_response`` function as the one reported below.

# %%
def generate_responses(model, prompt_examples):
  """
    This function implements the inference loop for a LLM model.
    Given a set of examples, the model is tasked to generate
    a response.

    Inputs:
      model: LLM model instance for prompting
      prompt_examples: pre-processed text samples

    Outputs:
      generated responses
  """
  response = model.generate(
      input_ids=prompt_examples['input_ids'],
      attention_mask=prompt_examples['attention_mask'],
      do_sample=False,
      max_new_tokens=1000, # higher due to reasoning model
                           # TODO: change it directly at the beginning
  )

  # Return only the new tokens
  # NOTE: all the prompts have the same lenght because of padding (?)
  input_length = prompt_examples['input_ids'].shape[1]
  generated_ids = response[:, input_length:]
  return generated_ids

# %%
import re

def process_response(response, debug=False):
    """
    This function takes a responseual response generated by the LLM
    and processes it to map the response to a binary label.

    Inputs:
      response: generated response from LLM

    Outputs:
      parsed classification response.
      Use the following mapping:
      {
        'not-sexist': 0,
        'threats': 1,
        'derogation': 2,
        'animosity': 3,
        'prejudiced': 4
      }
  """

    mapping = {
        'not-sexist': 0,
        'threats': 1,
        'derogation': 2,
        'animosity': 3,
        'prejudiced': 4
    }

    incomplete = False
    if "<think>" in response and "</think>" not in response:
        incomplete = True
        if debug:
            print("\t - Incomplete <think> tag detected")
    elif "</think>" in response:
        response = response.split("</think>")[-1].strip()

    response_lower = response.lower()
    response_length = len(response_lower)

    # Split into words once
    words = re.findall(r'\b\w+(?:-\w+)?\b', response_lower)

    # Check for explicit answer patterns first (high confidence)
    answer_patterns = [
        (r'\b(answer|conclusion|therefore|thus|classification|final answer)[:\s]+(\S+(?:-\S+)?)', 3),
        (r'\bthe (?:text|classification) is[:\s]+(\S+(?:-\S+)?)', 2),
    ]

    explicit_answer = None
    for pattern, confidence in answer_patterns:
        match = re.search(pattern, response_lower)
        if match:
            answer_text = match.groups()[-1].strip()
            for key in mapping.keys():
                if key in answer_text:
                    if debug:
                        print(f"\t   Found explicit answer: '{key}' (confidence: {confidence})")
                    explicit_answer = (key, confidence)
                    break
            if explicit_answer:
                break

    # If we found a high-confidence explicit answer, return it immediately
    if explicit_answer and explicit_answer[1] >= 3:
        return mapping[explicit_answer[0]]

    # Statistical scoring with position weighting
    scores = {key: 0.0 for key in mapping.keys()}

    for key in mapping.keys():
        pattern = r'\b' + re.escape(key) + r'\b'
        matches = list(re.finditer(pattern, response_lower))

        for match in matches:
            start = match.start()

            # Find the position in the word list
            # Count words before this position
            words_before_pos = len(re.findall(r'\b\w+(?:-\w+)?\b', response_lower[:start]))

            # Get 3 words before and 3 words after
            context_words_before = words[max(0, words_before_pos-3):words_before_pos]
            context_words_after = words[words_before_pos+1:words_before_pos+4]  # +1 to skip the key itself

            context_before = ' '.join(context_words_before)
            context_after = ' '.join(context_words_after)
            context = context_before + ' ' + context_after

            if debug:
                print(f"\t   Context for '{key}': ...{context_before} [{key}] {context_after}...")

            # Count how many other keys appear in this small context window
            other_keys_count = sum(1 for other_key in mapping.keys()
                                  if other_key != key and other_key in context)

            # If 2+ other keys in immediate context (2-3 words), it's likely a list
            if other_keys_count >= 2:
                if debug:
                    print(f"\t   Skipping '{key}' at {start} (in list with {other_keys_count} other keys)")
                continue

            # Check for comma/bullet patterns around the key (±10 chars)
            nearby = response_lower[max(0, start-10):min(response_length, start+len(key)+10)]
            if re.search(r'[,•\-\*]\s*' + re.escape(key) + r'\s*[,•\-\*]', nearby):
                if debug:
                    print(f"\t   Skipping '{key}' at {start} (comma/bullet list)")
                continue

            # Check for negation in the 3 words before
            if re.search(r'\b(not|no|isn\'t|aren\'t|neither|rather than)\b', context_before):
                scores[key] -= 2
                if debug:
                    print(f"\t   Found '{key}' with negation: -2 points")
                continue

            # Position-based scoring (normalized position in text)
            normalized_position = start / response_length if response_length > 0 else 0
            position_score = normalized_position

            # Check if near explicit answer indicators
            bonus = 0
            if re.search(r'\b(answer|conclusion|therefore|thus|classification)\b', context_before):
                bonus = 3
                if debug:
                    print(f"\t   Found '{key}' with answer indicator: +{bonus} bonus")

            total_score = position_score + bonus
            scores[key] += total_score

            if debug:
                print(f"\t   '{key}' at position {start} ({normalized_position:.2%}): +{total_score:.2f}")

    # Handle variations with same logic
    variations = {
        'not sexist': 'not-sexist',
        'non-sexist': 'not-sexist',
        'non sexist': 'not-sexist',
        'threat': 'threats',
        'threatening': 'threats',
        'derogatory': 'derogation',
        'degrade': 'derogation',
        'prejudice': 'prejudiced',
        'prejudicial': 'prejudiced'
    }

    for variation, canonical in variations.items():
        matches = list(re.finditer(r'\b' + re.escape(variation) + r'\b', response_lower))
        for match in matches:
            start = match.start()

            # Find position in word list
            words_before_pos = len(re.findall(r'\b\w+(?:-\w+)?\b', response_lower[:start]))

            context_words_before = words[max(0, words_before_pos-3):words_before_pos]
            context_words_after = words[words_before_pos+1:words_before_pos+4]

            context_before = ' '.join(context_words_before)
            context_after = ' '.join(context_words_after)
            context = context_before + ' ' + context_after

            # Count other keys/variations
            all_keys = list(mapping.keys()) + list(variations.keys())
            other_keys_count = sum(1 for k in all_keys if k != variation and k in context)

            if other_keys_count >= 2:
                continue

            # Negation check
            if re.search(r'\b(not|no|isn\'t|aren\'t|neither|rather than)\b', context_before):
                scores[canonical] -= 2
                continue

            # Position scoring
            normalized_position = start / response_length if response_length > 0 else 0
            position_score = normalized_position

            bonus = 0
            if re.search(r'\b(answer|conclusion|therefore|thus|classification)\b', context_before):
                bonus = 3

            scores[canonical] += position_score + bonus

    if debug:
        print(f"\t   Final scores: {scores}")

    # Return highest score
    max_score = max(scores.values())

    # If we had a medium-confidence explicit answer and no better score, use it
    if explicit_answer and max_score < explicit_answer[1]:
        return mapping[explicit_answer[0]]

    if max_score > 0:
        best_match = max(scores.items(), key=lambda x: x[1])
        if incomplete:
            print(f"\t - Incomplete answer → inferred: {best_match[0]} (score: {best_match[1]:.2f})")
        return mapping[best_match[0]]

    if debug:
        print("\t - No clear answer, defaulting to not-sexist")
    return 0

# %%
for model in models.values():
  model["tokenizer"].padding_side = 'left'  # for batch generation

# %%
# Define batch size
BATCH_SIZE = 8  # Adjust based on your GPU memory

results = {name: [] for name in models.keys()}
results.update({"true_label": [], "text": []})

# Process in batches
for i in range(0, len(test_df), BATCH_SIZE):
    batch_df = test_df.iloc[i:i+BATCH_SIZE]
    batch_texts = batch_df["text"].tolist()
    batch_labels = batch_df["label_category"].tolist()

    print(f"Processing batch {i//BATCH_SIZE + 1} ({len(batch_texts)} samples)")

    for name, model in models.items():
        print(f"\tProcessing with {name}...")

        # Prepare prompts for the entire batch
        prepared_prompts = prepare_prompts(batch_texts, prompt, model["tokenizer"])

        # Generate responses for the batch
        response_ids = generate_responses(model["model"], prepared_prompts)

        # Decode all responses at once
        responses = model["tokenizer"].batch_decode(
            response_ids,
            skip_special_tokens=True
        )

        # Process each response in the batch
        for response_text in responses:
            final_answer = process_response(response_text)
            results[name].append(final_answer)

    # Store true labels and texts
    results["true_label"].extend(batch_labels)
    results["text"].extend(batch_texts)

    print(f"Batch {i//BATCH_SIZE + 1} completed")
    print(50 * "-")
# Out:
# Processing batch 1 (10 samples)
# 	Processing with mistral...
# The following generation flags are not valid and may be ignored: ['top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: prejudiced
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	Processing with qwen...
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 7.98)
# 	 - Incomplete reasoning → inferred: prejudiced (score: 7.22)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: prejudiced (score: 13.77)
# 	 - Found exact label: not-sexist
# Batch 1 completed
# --------------------------------------------------
# Processing batch 2 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: prejudiced
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: derogation (score: 27.43)
# 	 - Found exact label: derogation
# 	 - Found exact label: prejudiced
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 23.77)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 12.02)
# Batch 2 completed
# --------------------------------------------------
# Processing batch 3 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: threats
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Incomplete reasoning → inferred: prejudiced (score: 7.85)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# Batch 3 completed
# --------------------------------------------------
# Processing batch 4 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: prejudiced
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: threats
# 	 - Found exact label: animosity
# 	 - Found exact label: threats
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: prejudiced (score: 8.54)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 22.64)
# 	 - Incomplete reasoning → inferred: derogation (score: 36.56)
# 	 - Incomplete reasoning → inferred: not-sexist (score: 23.51)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: not-sexist (score: 14.45)
# 	 - Incomplete reasoning → inferred: not-sexist (score: 8.81)
# 	 - Incomplete reasoning → inferred: not-sexist (score: 13.61)
# 	 - Incomplete reasoning → inferred: threats (score: 19.59)
# Batch 4 completed
# --------------------------------------------------
# Processing batch 5 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Found exact label: prejudiced
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Found exact label: prejudiced
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: prejudiced (score: 13.73)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 12.48)
# 	 - Incomplete reasoning → inferred: derogation (score: 35.34)
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: prejudiced (score: 13.39)
# Batch 5 completed
# --------------------------------------------------
# Processing batch 6 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: not-sexist
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: threats
# 	 - Found exact label: not-sexist
# 	 - Incomplete reasoning → inferred: derogation (score: 30.22)
# 	 - Incomplete reasoning → inferred: threats (score: 36.57)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 19.94)
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - No match found, defaulting to not-sexist
# 	 - Found exact label: derogation
# Batch 6 completed
# --------------------------------------------------
# Processing batch 7 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Found exact label: threats
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: threats (score: 28.19)
# 	 - Incomplete reasoning → inferred: derogation (score: 27.02)
# 	 - Found exact label: derogation
# Batch 7 completed
# --------------------------------------------------
# Processing batch 8 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: derogation (score: 11.98)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 30.78)
# 	 - Incomplete reasoning → inferred: prejudiced (score: 15.77)
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 9.17)
# 	 - Incomplete reasoning → inferred: not-sexist (score: 8.30)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# Batch 8 completed
# --------------------------------------------------
# Processing batch 9 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# 	 - Incomplete reasoning → inferred: derogation (score: 10.00)
# 	 - Incomplete reasoning → inferred: derogation (score: 30.47)
# 	 - Found exact label: threats
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 24.78)
# 	 - Incomplete reasoning → inferred: derogation (score: 16.42)
# 	 - Found exact label: not-sexist
# 	 - Incomplete reasoning → inferred: derogation (score: 29.39)
# Batch 9 completed
# --------------------------------------------------
# Processing batch 10 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: prejudiced (score: 1.06)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: prejudiced (score: 7.52)
# 	 - Incomplete reasoning → inferred: derogation (score: 24.74)
# 	 - Incomplete reasoning → inferred: derogation (score: 21.92)
# 	 - Incomplete reasoning → inferred: derogation (score: 19.30)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 30.93)
# 	 - Found exact label: derogation
# Batch 10 completed
# --------------------------------------------------
# Processing batch 11 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# 	 - Incomplete reasoning → inferred: derogation (score: 30.76)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 20.16)
# Batch 11 completed
# --------------------------------------------------
# Processing batch 12 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: derogation (score: 21.27)
# 	 - Incomplete reasoning → inferred: derogation (score: 27.25)
# 	 - Incomplete reasoning → inferred: derogation (score: 23.02)
# 	 - Incomplete reasoning → inferred: prejudiced (score: 13.34)
# 	 - Found exact label: not-sexist
# 	 - Incomplete reasoning → inferred: derogation (score: 8.60)
# 	 - Incomplete reasoning → inferred: not-sexist (score: 7.83)
# 	 - Incomplete reasoning → inferred: not-sexist (score: 8.65)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# Batch 12 completed
# --------------------------------------------------
# Processing batch 13 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: threats
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 14.56)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 35.16)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 9.56)
# 	 - Incomplete reasoning → inferred: not-sexist (score: 6.81)
# 	 - Incomplete reasoning → inferred: derogation (score: 31.22)
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# Batch 13 completed
# --------------------------------------------------
# Processing batch 14 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: not-sexist (score: 3.62)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 7.37)
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# Batch 14 completed
# --------------------------------------------------
# Processing batch 15 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: prejudiced
# 	 - Found exact label: derogation
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 17.06)
# 	 - Incomplete reasoning → inferred: derogation (score: 18.16)
# 	 - Found exact label: not-sexist
# 	 - Found exact label: not-sexist
# 	 - Incomplete reasoning → inferred: threats (score: 26.75)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 12.76)
# Batch 15 completed
# --------------------------------------------------
# Processing batch 16 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: prejudiced
# 	 - Found exact label: prejudiced
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: threats (score: 16.87)
# 	 - Incomplete reasoning → inferred: derogation (score: 33.09)
# 	 - Found exact label: not-sexist
# 	 - Found exact label: prejudiced
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Incomplete reasoning → inferred: derogation (score: 5.19)
# 	 - Incomplete reasoning → inferred: prejudiced (score: 0.56)
# 	 - Found exact label: derogation
# Batch 16 completed
# --------------------------------------------------
# Processing batch 17 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 9.20)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 13.63)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# Batch 17 completed
# --------------------------------------------------
# Processing batch 18 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: prejudiced
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: derogation (score: 30.26)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: threats (score: 20.64)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 27.57)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 11.03)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 13.85)
# Batch 18 completed
# --------------------------------------------------
# Processing batch 19 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: prejudiced (score: 15.39)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 28.97)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 9.10)
# 	 - Incomplete reasoning → inferred: derogation (score: 11.60)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# Batch 19 completed
# --------------------------------------------------
# Processing batch 20 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: threats
# 	 - Found exact label: prejudiced
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: derogation (score: 12.34)
# 	 - Incomplete reasoning → inferred: derogation (score: 25.98)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: threats (score: 26.01)
# 	 - Found exact label: derogation
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 47.97)
# 	 - Incomplete reasoning → inferred: prejudiced (score: 12.50)
# Batch 20 completed
# --------------------------------------------------
# Processing batch 21 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: threats
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: threats
# 	 - Found exact label: not-sexist
# 	 - Incomplete reasoning → inferred: threats (score: 42.55)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: not-sexist (score: 8.42)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 34.66)
# 	 - Incomplete reasoning → inferred: threats (score: 27.25)
# 	 - Found exact label: threats
# Batch 21 completed
# --------------------------------------------------
# Processing batch 22 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: threats
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: threats
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: threats
# 	 - Found exact label: not-sexist
# 	 - Found exact label: not-sexist
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# 	 - Incomplete reasoning → inferred: derogation (score: 14.59)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# Batch 22 completed
# --------------------------------------------------
# Processing batch 23 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: threats
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: threats
# 	 - Found exact label: threats
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: derogation (score: 21.01)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: prejudiced (score: 7.08)
# 	 - Incomplete reasoning → inferred: derogation (score: 25.88)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: threats (score: 27.09)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 42.64)
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# Batch 23 completed
# --------------------------------------------------
# Processing batch 24 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: prejudiced
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 15.38)
# 	 - No match found, defaulting to not-sexist
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 20.74)
# 	 - Incomplete reasoning → inferred: derogation (score: 21.66)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# Batch 24 completed
# --------------------------------------------------
# Processing batch 25 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# 	 - Found exact label: threats
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 20.38)
# 	 - Incomplete reasoning → inferred: derogation (score: 36.85)
# 	 - Incomplete reasoning → inferred: derogation (score: 23.02)
# 	 - Incomplete reasoning → inferred: derogation (score: 17.90)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# Batch 25 completed
# --------------------------------------------------
# Processing batch 26 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: prejudiced
# 	 - Found exact label: prejudiced
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: threats (score: 4.79)
# 	 - Incomplete reasoning → inferred: prejudiced (score: 4.13)
# 	 - Incomplete reasoning → inferred: derogation (score: 30.74)
# 	 - Incomplete reasoning → inferred: derogation (score: 23.39)
# 	 - Incomplete reasoning → inferred: threats (score: 16.92)
# 	 - Incomplete reasoning → inferred: derogation (score: 24.31)
# 	 - Found exact label: prejudiced
# 	 - Incomplete reasoning → inferred: prejudiced (score: 3.26)
# Batch 26 completed
# --------------------------------------------------
# Processing batch 27 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: derogation
# 	 - Found exact label: threats
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: not-sexist (score: 17.01)
# 	 - Incomplete reasoning → inferred: derogation (score: 24.32)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: threats (score: 31.39)
# 	 - Found exact label: not-sexist
# 	 - Incomplete reasoning → inferred: derogation (score: 28.37)
# 	 - Found exact label: derogation
# Batch 27 completed
# --------------------------------------------------
# Processing batch 28 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: threats
# 	Processing with qwen...
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: prejudiced (score: 7.61)
# 	 - Incomplete reasoning → inferred: derogation (score: 36.16)
# 	 - Incomplete reasoning → inferred: derogation (score: 17.91)
# 	 - Incomplete reasoning → inferred: prejudiced (score: 5.62)
# 	 - Incomplete reasoning → inferred: derogation (score: 9.60)
# 	 - Incomplete reasoning → inferred: derogation (score: 6.31)
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 9.52)
# 	 - Incomplete reasoning → inferred: threats (score: 22.55)
# Batch 28 completed
# --------------------------------------------------
# Processing batch 29 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: not-sexist
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: threats
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: threats (score: 17.60)
# 	 - Found exact label: threats
# 	 - Found exact label: threats
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: threats (score: 28.63)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 15.72)
# 	 - Found exact label: threats
# Batch 29 completed
# --------------------------------------------------
# Processing batch 30 (10 samples)
# 	Processing with mistral...
# 	 - Found exact label: prejudiced
# 	 - Found exact label: prejudiced
# 	 - Found exact label: threats
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: animosity
# 	 - Found exact label: derogation
# 	 - Found exact label: animosity
# 	 - Found exact label: prejudiced
# 	 - Found exact label: animosity
# 	Processing with qwen...
# 	 - Incomplete reasoning → inferred: prejudiced (score: 11.47)
# 	 - Incomplete reasoning → inferred: derogation (score: 16.12)
# 	 - Found exact label: threats
# 	 - Found exact label: derogation
# 	 - Incomplete reasoning → inferred: derogation (score: 26.41)
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# 	 - Found exact label: derogation
# Batch 30 completed
# --------------------------------------------------

# %%
import pickle
import pandas as pd

# path = '/content/drive/MyDrive/results.pkl'
path = './results.pkl'
with open(path, 'rb') as f : results = pickle.load(f)
# with open(path, 'wb') as f : pickle.dump(results, f)

# %%
results_df = pd.DataFrame(results)
results_df["true_label"] = results_df["true_label"].map({
        'not-sexist': 0,
        'threats': 1,
        'derogation': 2,
        'animosity': 3,
        'prejudiced': 4
    })
results_df
# Out:
#      mistral  qwen  true_label  \
# 0          3     0           2
# 1          4     2           4
# 2          3     2           2
# 3          4     2           4
# 4          4     2           4
# ..       ...   ...         ...
# 295        3     2           4
# 296        2     2           2
# 297        3     2           4
# 298        4     2           2
# 299        3     2           2
#
#                                                   text
# 0    She may be worth what someone paid for her in ...
# 1    The men who white knight for women eventually ...
# 2    Two thoughts to keep in mind about women and A...
# 3    Wimmin. No matter how good they have it, they'...
# 4    So just a few months ago, while Republican wom...
# ..                                                 ...
# 295  You can jack off to whatever you want dude. Ob...
# 296                                 girls have cooties
# 297  The comments are sickening. How is it rape if ...
# 298  I always thought fat activists (the philosophy...
# 299             god please make her go away evil bitch
#
# [300 rows x 4 columns]

# %% [markdown]
# ## Notes
#
# 1. According to our tests, it should take you ~10 mins to perform full inference on 300 samples on Colab.

# %% [markdown]
# # [Task 4 - 0.5 points] Metrics
#
# In order to evaluate selected LLMs, we need to compute performance metrics.
#
# We compute **macro F1-score** and the ratio of failed responses generated by models (**fail-ratio**).
#
# That is, how frequent the LLM fails to follow instructions and provides incorrect responses that do not address the classification task.
#
# In summary, we parse generated responses as follows:
# - **0** if 'not-sexist'
# - **1** if 'threats'
# - **2** if 'derogation'
# - **3** if 'animosity'
# - **4** if 'prejudiced'
# - **0** if the model does not answer in either way

# %% [markdown]
# ### Instructions
#
# In order to get Task 4 points, we require you to:
#
# * Write a ``compute_metrics`` function as the one reported below.
# * Compute metrics for the two selected LLMs.

# %%
from sklearn.metrics import f1_score
import numpy as np

def compute_metrics(y_pred, y_true):
  """
    This function takes predicted and ground-truth labels and compute
    metrics. In particular, this function compute accuracy and
    fail-ratio metrics. This function internally invokes
    `process_response` to compute metrics.

    Inputs:
      y_pred: parsed LLM responses
      y_true: ground-truth binary labels

    Outputs:
      dictionary containing desired metrics
  """
  y_pred = np.array(y_pred)
  y_true = np.array(y_true)

  macro_f1 = f1_score(y_true, y_pred, average="macro")

  failed = (y_pred == 0) & (y_true != 0)
  fail_ratio = failed.sum() / len(y_pred)

  return {
      "macro_f1": macro_f1,
      "fail_ratio": fail_ratio
  }

# %%
metrics_mistral = compute_metrics(results_df['mistral'], results_df['true_label'])
metrics_qwen = compute_metrics(results_df['qwen'], results_df['true_label'])

print(f"Mistral:"); display(pd.DataFrame([metrics_mistral]))
print(f"Qwen:"); display(pd.DataFrame([metrics_qwen]))
# Out:
# Mistral:
#    macro_f1  fail_ratio
# 0  0.367888    0.013333
# Qwen:
#    macro_f1  fail_ratio
# 0  0.288698    0.053333

# %%
import matplotlib.pyplot as plt
results_df['true_label'].hist(); plt.show()
results_df['qwen'].hist(); plt.show()
results_df['mistral'].hist(); plt.show()

# %% [markdown]
# # [Task 5 - 1.0 points] Few-shot Inference
#
# So far, we have tested models in a zero-shot fashion: we provide the input text to classify and instruct the model to generate a response.
#
# We are now interested in performing few-shot prompting to see the impact of providing demonstration examples.
#
# To do so, we slightly change the prompt template as follows.

# %%
prompt = [
    {
        'role': 'system',
        'content': 'You are an annotator for sexism detection.'
    },
    {
        'role': 'user',
        'content': """Your task is to classify input text as not-sexist
         or sexist. If sexist, classify input text according to one
         of the following four categories: threats, derogation,
         animosity, prejudiced discussion.

         Below you find sexist categories definitions:
         Threats: the text expresses intent or desire to harm a woman.
         Derogation: the text describes a woman in a derogative manner.
         Animosity: the text contains slurs or insults towards a woman.
         Prejudiced discussion: the text expresses supports for
         mistreatment of women as individuals.

         Respond only by writing one of the following categories:
         not-sexist, threats, derogation, animosity, prejudiced.

        EXAMPLES: {examples}

        TEXT: {text}

        ANSWER:
        """
    }
]

# %% [markdown]
# The new prompt template reports some demonstration examples to instruct the model.
#
# Generally, we provide an equal number of demonstrations per class as shown in the example below.

# %%
prompt = [
    {
        'role': 'system',
        'content': 'You are an annotator for sexism detection.'
    },
    {
        'role': 'user',
        'content': """Your task is to classify input text as not-sexist
         or sexist. If sexist, classify input text according to one
         of the following four categories: threats, derogation,
         animosity, prejudiced discussion.

         Below you find sexist categories definitions:
         Threats: the text expresses intent or desire to harm a woman.
         Derogation: the text describes a woman in a derogative manner.
         Animosity: the text contains slurs or insults towards a woman.
         Prejudiced discussion: the text expresses supports for
         mistreatment of women as individuals.

         Respond only by writing one of the following categories:
         not-sexist, threats, derogation, animosity, prejudiced.

         EXAMPLES:
         TEXT: **example 1**
         ANSWER: threats
         TEXT: **example 2**
         ANSWER: not-sexist

         TEXT: {text}

        ANSWER:
        """
    }
]

# %% [markdown]
# ## Instructions
#
# In order to get Task 5 points, we require you to:
#
# - Load ``demonstrations.csv`` and encode it into a ``pandas.DataFrame`` object.
# - Define a ``build_few_shot_demonstrations`` function as the one reported below.
# - Modify ``prepare_prompts`` to support demonstrations.
# - Perform few-shot inference as in Task 3.
# - Compute metrics as in Task 4.

# %%
data_path = "./nlp-course-material/2025-2026/Assignment 2/data/"
demostration_df = pd.read_csv(data_path + "demonstrations.csv")

# %%
import random
def build_few_shot_demonstrations(demonstrations, num_per_class=2):
  """
    Inputs:
      demonstrations: DataFrame wrapping demonstrations.csv
      num_per_class: number of demonstrations per class

    Outputs:
      list of demonstrations to inject into the prompt template.
  """
  category_texts = demostration_df\
                    .groupby("label_category")["text"]\
                    .apply(list)\
                    .to_dict()

  selected_examples = {category:random.sample(texts, num_per_class)
                       for category, texts in category_texts.items()}
  
  examples_format = "\n"
  for category, class_examples in selected_examples.items():
    for example in class_examples:
      examples_format += f"TEXT: {example}\nANSWER: {category}\n"
      
  return examples_format

# %%
print(build_few_shot_demonstrations(demostration_df))
# Out:
# TEXT: The lawyer chick will shoot down the McDonald's guy, every time, no matter how he looks. That's just the world that we live in. Agree to disagree, I suppose.
# ANSWER: animosity
# TEXT: [USER] The #feminazi journo can hardly restrain her joy at man hating. #feminism #MRAs
# ANSWER: animosity
# TEXT: i hope sex robots are a thing soon, i hate having to interact with women who will never date or fuck me
# ANSWER: derogation
# TEXT: No, say it ain't so! Wow! You mean the women are finally waking up? The Lord be praised and all that! Now let us see the men joining in and we might get the Saxon finally waking the fuck up!
# ANSWER: derogation
# TEXT: You’ll get mogged by anyone with same features but taller than you. Dan Bilzerian is probably a good example like him or hate him
# ANSWER: not-sexist
# TEXT: I don't think she would be able to swing a .50 cal as well as a GLOCK or S&W
# ANSWER: not-sexist
# TEXT: Cope. Don't believe what women say but rather what they do. They love virtue signaling that they have evil white oppressors while love being oppressed by the same people. [URL]
# ANSWER: prejudiced
# TEXT: Posting sexy selfies is a viable strategy for low-income young women. Women who flaunt what they've got are not "victims of the patriarchy" but instead exploiting "the pot of capital that youth bestows on them". [URL]
# ANSWER: prejudiced
# TEXT: I would have loved so loved to have been there to run up on her and hit her in the face yelling maga hat! punch a Nazi!!
# ANSWER: threats
# TEXT: Translation: "sexually assaulting/harassing women is almost as good as if not better than consensual sex".
# ANSWER: threats

# %%
example_format_prompt = prompt.format(examples=build_few_shot_demonstrations(demostration_df))

# %% [markdown]
# ## Notes
#
# 1. You are free to pick any value for ``num_per_class``.
#
# 2. According to our tests, few-shot prompting increases inference time by some minutes (we experimented with ``num_per_class`` $\in [2, 4]$).

# %% [markdown]
# # [Task 6 - 1.0 points] Error Analysis
#
# We are now interested in evaluating model responses and comparing their performance.
#
# This analysis helps us in understanding
#
# - Classification task performance gap: are the models good at this task?
# - Generation quality: which kind of responses do models generate?
# - Errors: which kind of mistakes do models do?

# %% [markdown]
# ### Instructions
#
# In order to get Task 6 points, we require you to:
#
# * Compare classification performance of selected LLMs in a Table.
# * Compute confusion matrices for selected LLMs.
# * Briefly summarize your observations on generated responses.

# %% [markdown]
# # [Task 7 - 1.0 points] Report
#
# Wrap up your experiment in a short report (up to 2 pages).

# %% [markdown]
# ### Instructions
#
# * Use the NLP course report template.
# * Summarize each task in the report following the provided template.

# %% [markdown]
# ### Recommendations
#
# The report is not a copy-paste of graphs, tables, and command outputs.
#
# * Summarize classification performance in Table format.
# * **Do not** report command outputs or screenshots.
# * Report learning curves in Figure format.
# * The error analysis section should summarize your findings.

# %% [markdown]
# # Submission
#
# * **Submit** your report in PDF format.
# * **Submit** your python notebook.
# * Make sure your notebook is **well organized**, with no temporary code, commented sections, tests, etc...

# %% [markdown]
# # FAQ
#
# Please check this frequently asked questions before contacting us.

# %% [markdown]
# ### Model cards
#
# You can pick any open-source model card you like.
#
# We recommend starting from those reported in this assignment.

# %% [markdown]
# ### Implementation
#
# Everything can be done via ``transformers`` APIs.
#
# However, you are free to test frameworks, such as [LangChain](https://www.langchain.com/), [LlamaIndex](https://www.llamaindex.ai/) [LitParrot](https://github.com/awesome-software/lit-parrot), provided that you correctly address task instructions.

# %% [markdown]
# ### Task Performance
#
# The task is challenging and zero-shot prompting may show relatively low performance depending on the chosen model.

# %% [markdown]
# ### Prompt Template
#
# Do not change the provided prompt template.
#
# You are only allowed to change it in case of a possible extension.

# %% [markdown]
# ### Optimizations
#
# Any kind of code optimization (e.g., speedup model inference or reduce computational cost) is more than welcome!

# %% [markdown]
# ### Bonus Points
#
# 0.5 bonus points are arbitrarily assigned based on significant contributions such as:
#
# - Outstanding error analysis
# - Masterclass code organization
# - Evaluate A1 dataset and perform comparison
# - Perform prompt tuning
#
# Note that bonus points are only assigned if all task points are attributed (i.e., 6/6).

# %% [markdown]
# # The End
