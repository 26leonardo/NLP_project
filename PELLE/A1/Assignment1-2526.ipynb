# %% [markdown]
# # Assignment 1
# **Credits**: Federico Ruggeri, Eleonora Mancini, Paolo Torroni
#
# **Keywords**: Sexism Detection, Multi-class Classification, RNNs, Transformers, Huggingface

# %% [markdown]
# # Contact
# For any doubt, question, issue or help, you can always contact us at the following email addresses:
#
# Teaching Assistants:
#
# - Federico Ruggeri -> federico.ruggeri6@unibo.it
# - Eleonora Mancini -> e.mancini@unibo.it
#
# Professor:
# - Paolo Torroni -> p.torroni@unibo.it

# %% [markdown]
# # Introduction
# You are asked to address the [EXIST 2023 Task 2](https://clef2023.clef-initiative.eu/index.php?page=Pages/labs.html#EXIST) on sexism detection.

# %% [markdown]
# ## Problem Definition
#
# This task aims to categorize the sexist messages according to the intention of the author in one of the following categories: (i) direct sexist message, (ii) reported sexist message and (iii) judgemental message.

# %% [markdown]
# ### Examples:
#
# #### DIRECT
# The intention was to write a message that is sexist by itself or incites to be sexist, as in:
#
# ''*A woman needs love, to fill the fridge, if a man can give this to her in return for her services (housework, cooking, etc), I don’t see what else she needs.*''

# %% [markdown]
# #### REPORTED
# The intention is to report and share a sexist situation suffered by a woman or women in first or third person, as in:
#
# ''*Today, one of my year 1 class pupils could not believe he’d lost a race against a girl.*''

# %% [markdown]
# #### JUDGEMENTAL
# The intention was to judge, since the tweet describes sexist situations or behaviours with the aim of condemning them.
#
# ''*As usual, the woman was the one quitting her job for the family’s welfare…*''

# %%
# Package requirements
! pip install --upgrade pip
! pip install emoji pandas nltk gensim numpy tensorflow matplotlib scikit-learn
# Out:
# /Users/pelle/.zshenv:.:6: no such file or directory: /usr/local/env
# ...
# /Users/pelle/.zshenv:.:6: no such file or directory: /usr/local/env
# ...

# %%
# Standard library
import os
import re
import json
from collections import Counter, defaultdict

# Third-party libraries
import numpy as np
import pandas as pd
import emoji
import gensim
import gensim.downloader as gloader
import nltk
from nltk import pos_tag, word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from tensorflow.keras.preprocessing.text import Tokenizer
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Layer, Bidirectional, LSTM, Dense, Dropout, Embedding

# Typing
from typing import List, Dict, Tuple, Set

# %% [markdown]
# # [Task 1 - 1.0 points] Corpus
#
# We have preparared a small version of EXIST dataset in our dedicated [Github repository](https://github.com/lt-nlp-lab-unibo/nlp-course-material/tree/main/2025-2026/Assignment%201/data).
#
# Check the `A1/data` folder. It contains 3 `.json` files representing `training`, `validation` and `test` sets.

# %% [markdown]
# ### Dataset Description
# - The dataset contains tweets in both English and Spanish.
# - There are labels for multiple tasks, but we are focusing on **Task 2**.
# - For Task 2, labels are assigned by six annotators.
# - The labels for Task 2 represent whether the tweet is non-sexist ('-') or its sexist intention ('DIRECT', 'REPORTED', 'JUDGEMENTAL').

# %% [markdown]
# ### Example
#
# ```
#     "203260": {
#         "id_EXIST": "203260",
#         "lang": "en",
#         "tweet": "ik when mandy says “you look like a whore” i look cute as FUCK",
#         "number_annotators": 6,
#         "annotators": ["Annotator_473", "Annotator_474", "Annotator_475", "Annotator_476", "Annotator_477", "Annotator_27"],
#         "gender_annotators": ["F", "F", "M", "M", "M", "F"],
#         "age_annotators": ["18-22", "23-45", "18-22", "23-45", "46+", "46+"],
#         "labels_task1": ["YES", "YES", "YES", "NO", "YES", "YES"],
#         "labels_task2": ["DIRECT", "DIRECT", "REPORTED", "-", "JUDGEMENTAL", "REPORTED"],
#         "labels_task3": [
#           ["STEREOTYPING-DOMINANCE"],
#           ["OBJECTIFICATION"],
#           ["SEXUAL-VIOLENCE"],
#           ["-"],
#           ["STEREOTYPING-DOMINANCE", "OBJECTIFICATION"],
#           ["OBJECTIFICATION"]
#         ],
#         "split": "TRAIN_EN"
#       }
#     }
# ```

# %% [markdown]
# ### Instructions
# 1. **Download** the `A1/data` folder.
# 2. **Load** the three JSON files and encode them as ``pandas.DataFrame``.
# 3. **Aggregate labels** for Task 2 using majority voting and store them in a new dataframe column called `label`. Items without a clear majority will be removed from the dataset.
# 4. **Filter the DataFrame** to keep only rows where the `lang` column is `'en'`.
# 5. **Remove unwanted columns**: Keep only `id_EXIST`, `lang`, `tweet`, and `label`.
# 6. **Encode the `label` column**: Use the following mapping
#
# ```
# {
#     '-': 0,
#     'DIRECT': 1,
#     'JUDGEMENTAL': 2,
#     'REPORTED': 3
# }
# ```

# %%
# Load and encode the jsons
train_df = pd.DataFrame(json.load(open('./data/training.json'))).transpose()
test_df = pd.DataFrame(json.load(open('./data/test.json'))).transpose()
val_df = pd.DataFrame(json.load(open('./data/validation.json'))).transpose()
dfs = [train_df, val_df, test_df]

print("Before:", train_df.shape, val_df.shape, test_df.shape)

for i, df in enumerate(dfs):
    # Aggregate labels by majority vote, only keep rows with unique majority
    majority_labels = []
    for labels in df["labels_task2"]:
        c = Counter(labels).most_common(2)
        if len(c)==1:
            majority_labels.append(c[0][0])
        elif c[1][1] < c[0][1]:
            majority_labels.append(c[0][0])
        else:
            majority_labels.append(None)
    df["label"] = majority_labels
    df = df.dropna(subset=["label"]).reset_index(drop=True)

    # Filter rows with language "en"
    df = df[df["lang"]=="en"].reset_index(drop=True)
    df = df[["id_EXIST", "lang", "tweet", "label"]]

    # Encode labels as integers
    label_mapping = {"-":0, "DIRECT":1, "JUDGEMENTAL":2, "REPORTED":3}
    reverse_mapping = {v: k for k, v in label_mapping.items()}  # TODO: utile per debug ma togliere dopo
    df["label"] = df["label"].map(label_mapping)

    dfs[i] = df # NOTE: we have to do this otherwise the changes won't persist


train_df, val_df, test_df = dfs
print("After: ", train_df.shape, val_df.shape, test_df.shape)
# Out:
# Before: (6920, 11) (726, 11) (312, 11)
# After:  (2873, 4) (150, 4) (280, 4)

# %% [markdown]
# # [Task2 - 0.5 points] Data Cleaning
# In the context of tweets, we have noisy and informal data that often includes unnecessary elements like emojis, hashtags, mentions, and URLs. These elements may interfere with the text analysis.

# %% [markdown]
# ### Instructions
# - **Remove emojis** from the tweets.
# - **Remove hashtags** (e.g., `#example`).
# - **Remove mentions** such as `@user`.
# - **Remove URLs** from the tweets.
# - **Remove special characters and symbols**.
# - **Remove specific quote characters** (e.g., curly quotes).
# - **Perform lemmatization** to reduce words to their base form.

# %%
# Download required NLTK data
# NOTE: this is mostly from the lab, mayeb it's not the most efficient way
os.makedirs("nltk_data", exist_ok=True)
nltk.download('omw-1.4', download_dir="./nltk_data")
nltk.download('wordnet', download_dir="./nltk_data")
nltk.download('averaged_perceptron_tagger', download_dir="./nltk_data")
nltk.download('averaged_perceptron_tagger_eng', download_dir="./nltk_data")
nltk.download('punkt_tab', download_dir="./nltk_data")
nltk.data.path.append("./nltk_data")

lemmatizer = WordNetLemmatizer()

def pos2wordnet_tag(treebank_tag: str) -> str:
    match treebank_tag[0]:
        case "J":   return wordnet.ADJ
        case "V":   return wordnet.VERB
        case "N":   return wordnet.NOUN
        case "R":   return wordnet.ADV
        case _:     return wordnet.NOUN

def token_lemma(text: str) -> str:
    """
    Tokenize the text, then lemmatize the tokens and then merge the lemmatized tokens into a text
    """
    tokens = word_tokenize(text)    # usese recommended NLTK tokenizer
    tagged_tokens = pos_tag(tokens)
    lemmatized_tokens = [
        lemmatizer.lemmatize(tok.lower(), pos2wordnet_tag(pos))
        for tok, pos in tagged_tokens
    ]
    return " ".join(lemmatized_tokens)

# NOTE: we replace chars with space to avoid merging words during the process, the tokenizer will take care of extra spaces.
def clean_text(text, patterns):
    
    # 1) Remove emojis
    # NOTE: we asked the tutors and they said that it is meant to remove only visible emojis, not text-based ones. We used the emoji library for completeness.
    # NOTE: the tutor said that we could delete or replace with text, since there are already text emoji we can't handle it could be interesting to replace them with text in order to cover them properly. On the other hand text emoji are rare in the dataset and are for sure used in a different way.
    # NOTE; we don't include the regex for emojis here since we are using the emoji library and it is more efficient and complete.
    text = emoji.replace_emoji(text, replace=' ')    
    
    # Remove other patterns
    for pattern in patterns:
        text = pattern.sub(' ', text) 
    
    # Tokenize, lemmatize and merge
    return token_lemma(text)
# Out:
# [nltk_data] Downloading package omw-1.4 to ./nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to ./nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     ./nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     ./nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to ./nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
# NOTE: 1 big regex for all patterns would be more efficient, but here we prefer to keep them separate for clarity

patterns = [
    
    # 2) Hashtags
    re.compile(r'#\w+'),
    
    # 3) Mentions
    re.compile(r'@\w+'),
    
    # 4) URLs
    re.compile(r'https?://[^\s]+'), 
    
    # 6) Specific quotes characters, i assume not the regular ones (e.g. " ' )
    # NOTE: we do this here explicitely in order not to implicitly remove them with the special characters pattern
    re.compile(r'[“”‘’«»`´]'), 
    
    # 5) Special characters and symbols
    # NOTE: we asked the tutors as it was ambiguous and they said they meant all non-alphanumeric characters, considering also quotes, parentheses, punctuation, etc.
    re.compile(r'[^a-zA-Z0-9\s]'),

]

for i, df in enumerate(dfs):
    df['cleaned_tweet'] = df["tweet"].apply(lambda text: clean_text(text, patterns))
    
    # TODO: only for train set, maybe apply more complex cleaning:
    # 1) remove noisy chars due to simple removal
    # 2) compression of repeated punctuation
    # 3) MAYBE: html tags, mnore complex and noisy patterns (es. 10%-)
    if i==0: 
        pass
        
    dfs[i] = df    

display(train_df[["tweet", "cleaned_tweet"]])
# Out:
#                                                   tweet  \
# 0     FFS! How about laying the blame on the bastard...
# 1     Writing a uni essay in my local pub with a cof...
# 2     @UniversalORL it is 2021 not 1921. I dont appr...
# 3     @GMB this is unacceptable. Use her title as yo...
# 4     ‘Making yourself a harder target’ basically bo...
# ...                                                 ...
# 2868  @ShefVaidya Ma'am if I say that you look like ...
# 2869  idk why y’all bitches think having half your a...
# 2870  This has been a part of an experiment with @Wo...
# 2871  "Take me already" "Not yet. You gotta be ready...
# 2872  @clintneedcoffee why do you look like a whore?...
#
#                                           cleaned_tweet
# 0     ffs how about lay the blame on the bastard who...
# 1     write a uni essay in my local pub with a coffe...
# 2     it be 2021 not 1921 i dont appreciate that on ...
# 3     this be unacceptable use her title a you do fo...
# ...

# %%
def build_word_listing(df):
    vocab = set()
    tokens_vec=[]
    for text in df["cleaned_tweet"]:
        # NOTE: we use split since they were already tokenized and then jointed with spaces
        tokens = text.split(" ")
        vocab.update(tokens)
        tokens_vec.append(tokens)
    return sorted(vocab), tokens_vec

word_listing_train, train_corpus = build_word_listing(train_df)
word_listing_val, val_corpus = build_word_listing(val_df)
word_listing_test, test_corpus = build_word_listing(test_df)

# %% [markdown]
# # [Task 3 - 0.5 points] Text Encoding
# To train a neural sexism classifier, you first need to encode text into numerical format.

# %% [markdown]
# ### Instructions
#
# * Embed words using **GloVe embeddings**.
# * You are **free** to pick any embedding dimension.

# %% [markdown]
# ### What about OOV tokens?
#    * All the tokens in the **training** set that are not in GloVe **must** be added to the vocabulary.
#    * For the remaining tokens (i.e., OOV in the validation and test sets), you have to assign them a **special token** (e.g., ``<UNK>``) and a **static** embedding.
#    * You are **free** to define the static embedding using any strategy (e.g., random, neighbourhood, etc...)

# %% [markdown]
# ### More about OOV
#
# For a given token:
#
# * **If in train set**: add to vocabulary and assign an embedding (use GloVe if token in GloVe, custom embedding otherwise).
# * **If in val/test set**: assign special token if not in vocabulary and assign custom embedding.
#
# Your vocabulary **should**:
#
# * Contain all tokens in train set; or
# * Union of tokens in train set and in GloVe $\rightarrow$ we make use of existing knowledge!

# %%
# Hyperparams
WINDOW_SIZE = 50
EMBEDDING_DIMENSION = 50
OOV_TOKEN = "<OOV>"

# %%
# FUNCTIONS

def load_embedding_model(
    model_type: str,
    embedding_dimension: int = 50
) -> gensim.models.keyedvectors.KeyedVectors:
    
    """
    Load pre-trained embedding model (Word2Vec, GloVe, FastText).

    :param model_type: 'word2vec', 'glove', or 'fasttext'
    :param embedding_dimension: embedding size (only used for GloVe)
    :return: gensim KeyedVectors object
    """
    
    types = {
        "word2vec" : "word2vec-google-news-300",
        "glove" : f"glove-wiki-gigaword-{embedding_dimension}",
        "fasttext" : "fasttext-wiki-news-subwords-300"
    }
    
    model_type_lower = model_type.strip().lower()
    if model_type_lower not in types.keys():
        raise ValueError(f"Unsupported embedding model type. Use {', '.join(list(types.keys()))}")
    else:
        path = types[model_type_lower]
        
    try:
        return gloader.load(path)
    except ValueError as e:
        raise ValueError("Failed to load embedding. Check dimension compatibility.") from e


def build_alacarte_transform(
    train_corpus: List[List[str]],
    embedding_model: gensim.models.keyedvectors.KeyedVectors,
    window_size: int = 5
) -> np.ndarray:
    
    """
    Compute A-La-Carte transformation matrix from a training corpus.

    Reference:
    Khodak, M., Saunshi, N., & Liang, P. (2018).
    "A La Carte Embedding: Cheap but Effective Induction of Semantic Feature Vectors."
    ACL 2018.

    :param train_corpus: tokenized training corpus
    :param embedding_model: pre-trained embedding model
    :param window_size: size of context window for each word
    :return: transformation matrix A (embedding_dim x embedding_dim)
    """
    
    context_vectors = {}
    context_counts = {}

    # Build averaged context vectors for each word
    for sentence in train_corpus:
        for i, word in enumerate(sentence):
            
            # Skip words without a pretrained embedding as they cannot serve as regression targets
            if word not in embedding_model:
                continue 
            
            # Collect embeddings for neighboring [+window_size, -window_size], excluding the current word
            start = max(0, i - window_size)
            end = min(len(sentence), i + window_size + 1)
            context = [embedding_model[w] for w in sentence[start:i] + sentence[i+1:end] if w in embedding_model]
            if context:
                avg_ctx = np.mean(context, axis=0)
                if word in context_vectors:
                    context_vectors[word] += avg_ctx
                    context_counts[word] += 1
                else:
                    context_vectors[word] = avg_ctx
                    context_counts[word] = 1

    # Normalize by occurrences
    for word in context_vectors:
        context_vectors[word] /= context_counts[word]

    U = np.array([context_vectors[w] for w in context_vectors])
    V = np.array([embedding_model[w] for w in context_vectors])
    
    # Linear regression to find transformation matrix
    A = np.linalg.lstsq(U, V, rcond=None)[0].T
    return A


def build_vocabulary_train_union(
    train_corpus: List[List[str]],
    embedding_model: gensim.models.keyedvectors.KeyedVectors
) -> Tuple[Set[str], Set[str]]:
    
    """
    Union of training tokens and embedding vocabulary.

    :return: (vocabulary union, training tokens)
    """
    
    train_tokens = set(tok for sent in train_corpus for tok in sent)
    embedding_vocab = set(embedding_model.index_to_key)
    vocabulary = train_tokens | embedding_vocab
    return vocabulary, train_tokens


def create_custom_embeddings_for_train_oov(
    train_corpus: List[List[str]],
    embedding_model: gensim.models.keyedvectors.KeyedVectors,
    transform_matrix: np.ndarray
) -> Dict[str, np.ndarray]:
    
    """
    Generate embeddings for training OOV tokens using A-La-Carte.
    
    Reference:
    Khodak, M., Saunshi, N., & Liang, P. (2018).
    "A La Carte Embedding: Cheap but Effective Induction of Semantic Feature Vectors."
    ACL 2018.

    :return: dict mapping OOV token -> embedding vector
    """
    
    embedding_dim = embedding_model.vector_size
    train_tokens = set(tok for sent in train_corpus for tok in sent)
    train_oov = train_tokens - set(embedding_model.index_to_key)

    # Collect contexts for OOV tokens
    oov_contexts = defaultdict(list)
    for sentence in train_corpus:
        for word in sentence:
            if word in train_oov:
                context = [w for w in sentence if w != word and w in embedding_model]
                if context:
                    oov_contexts[word].append(context)

    # Compute the embedding based on OOV contexts, if any
    custom_embeddings = {}
    for word in train_oov:
        if oov_contexts[word]:
            avg_vecs = [np.mean([embedding_model[w] for w in ctx], axis=0) for ctx in oov_contexts[word]]
            final_context = np.mean(avg_vecs, axis=0)
            custom_embeddings[word] = transform_matrix @ final_context
        else:
            custom_embeddings[word] = np.random.normal(0, 0.1, embedding_dim)

    return custom_embeddings


def build_tokenizer_with_vocabulary(
    vocabulary: Set[str],
    train_tokens: Set[str],
    oov_token: str = "<OOV>"
) -> Tokenizer:
    
    """
    Build a Keras tokenizer from a fixed vocabulary.
    Fits on train_tokens first, then statically adds remaining vocabulary tokens.
    
    :param vocabulary: Complete vocabulary (train + embedding tokens)
    :param train_tokens: Tokens from training corpus only
    :param oov_token: Token to use for out-of-vocabulary words
    :return: Configured tokenizer with full vocabulary
    """
    
    tokenizer = Tokenizer(oov_token=oov_token)
    
    # Dynamic tokenization: fit on training tokens
    # NOTE: This automatically adds OOV token at index 1 and reserves index 0 for padding
    tokenizer.fit_on_texts([' '.join(train_tokens)]) 
    
    # Static addition: add embedding tokens not in training set
    # NOTE: We add these statically because GloVe tokens may contain special chars
    # (punctuation, URLs, etc.) that Keras tokenizer would split during fitting
    max_idx = max(tokenizer.word_index.values()) 
    for token in sorted(vocabulary - train_tokens):
        max_idx += 1
        tokenizer.word_index[token] = max_idx
    tokenizer.index_word = {idx: word for word, idx in tokenizer.word_index.items()}
    tokenizer.document_count = len(vocabulary)
    
    return tokenizer


def build_embedding_matrix(
    tokenizer: Tokenizer,
    embedding_model: gensim.models.keyedvectors.KeyedVectors,
    train_custom_embeddings: Dict[str, np.ndarray],
    oov_token: str = "<OOV>",
    verbose: bool = False,
    debug_dict: dict = None
) -> np.ndarray:
    """
    Construct embedding matrix for Keras model: pre-trained + custom embeddings.

    :return: embedding matrix (vocab_size x embedding_dim)
    """
    embedding_dim = embedding_model.vector_size
    vocab_size = len(tokenizer.word_index) + 1
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    
    glove_count = 0
    custom_count = 0
    others_count = 0

    for word, idx in tokenizer.word_index.items():
        if word == oov_token:
            # OOV token gets a small random vector
            # NOTE: it will be updated at inference time by considering the context in the test/val batch
            embedding_matrix[idx] = np.random.normal(0, 0.1, embedding_dim)
            if verbose : print(f"[OOV]       idx={idx} -> random vector")
            if debug_dict is not None: debug_dict["OOV"]=word

        elif word in embedding_model:
            # Pre-trained embedding exists 
            embedding_matrix[idx] = embedding_model[word]
            glove_count += 1  
            if verbose : print(f"[PRE-TRAIN] idx={idx} '{word}' -> pre-trained embedding")
            if debug_dict is not None: debug_dict["PRE-TRAIN"]=word

        elif word in train_custom_embeddings:
            # Custom embedding available
            embedding_matrix[idx] = train_custom_embeddings[word]
            custom_count += 1 
            if verbose : print(f"[CUSTOM]    idx={idx} '{word}' -> custom embedding")
            if debug_dict is not None: debug_dict["CUSTOM"]=word

        else:
            # Word not found in any embedding source, assign random vector
            # NOTE: this shouldn't happen
            embedding_matrix[idx] = np.random.normal(0, 0.1, embedding_dim)
            others_count += 1
            if verbose : print(f"[ELSE]      idx={idx} '{word}' -> no embedding found, random vector")
            if debug_dict is not None: debug_dict["ELSE"]=word

    if verbose:
        print(f"Embedding matrix built: {glove_count} pre-trained, {custom_count} custom, {others_count} others")
        
    return embedding_matrix

# %%
# Load embedding model
embedding_model = load_embedding_model("glove", EMBEDDING_DIMENSION)

# Build A-La-Carte transformation matrix
A = build_alacarte_transform(train_corpus, embedding_model, window_size=WINDOW_SIZE)

# Create vocabulary union
vocabulary, train_tokens = build_vocabulary_train_union(train_corpus, embedding_model)

# Generate custom embeddings for training OOV tokens
train_custom_embeddings = create_custom_embeddings_for_train_oov(
    train_corpus, embedding_model, A
)

# Build tokenizer with full vocabulary
tokenizer = build_tokenizer_with_vocabulary(vocabulary, train_tokens, oov_token=OOV_TOKEN)
vocab_size = len(tokenizer.word_index) + 1 # +1 for index 0 for padding

print(f"Vocabulary size: {vocab_size}")

# Build embedding matrix
embedding_matrix = build_embedding_matrix(
    tokenizer, embedding_model, train_custom_embeddings, oov_token=OOV_TOKEN,
    verbose=False
)

print(f"Embedding matrix shape: {embedding_matrix.shape}")

# NOTE: the test/val OOV will be handled at inference time thanks to the contexts of the batches
# Out:
# Vocabulary size: 400932
# Embedding matrix shape: (400932, 50)

# %% [markdown]
# ## Extra: visualization of embedding

# %%
token_to_embedding = {word : embedding_matrix[idx] for word, idx in tokenizer.word_index.items()}
tokens = list(token_to_embedding.keys())
embeddings = np.array([token_to_embedding[t] for t in tokens])

# NOTE: the 3d reduction wasn't more informative so we kept only this one
pca_2d = PCA(n_components=2)
embeddings_2d = pca_2d.fit_transform(embeddings)
token_to_2d = {token: embeddings_2d[i] for i, token in enumerate(tokens)}

# Separate tokens into pretrained (from GloVe) and custom (A-La-Carte generated)
pretrained_tokens = set(embedding_model.index_to_key)
custom_tokens = set(train_custom_embeddings.keys())

# Get embeddings for each category
pretrained_coords = np.array([token_to_2d[t] for t in tokens if t in pretrained_tokens])
custom_coords = np.array([token_to_2d[t] for t in tokens if t in custom_tokens])

# Define gender-paired tuples
# TODO: add more and more informative
gender_pairs = (
    (("king", "queen"), ("prince", "princess")),
    (("man", "woman"), ("boy", "girl")),
    (("father", "mother"), ("son", "daughter"), ("grandfather", "grandmother"), ("uncle", "aunt")),
    (("he", "she"), ("him", "her")),
)
word_groups = [(
    word 
    for pair in group 
    for word in pair 
) for group in gender_pairs]

# Define up to 10 distinct colors for the groups 
group_colors = [ 
    "red", "blue", "black", "purple", "orange",
    "pink", "cyan", "magenta", "black", "yellow",
    "brown" 
]

plt.figure(figsize=tuple(np.array((10,10)) * 1)) # NOTE: to easysily scale the plot

# Plot pretrained tokens in green and custom tokens in gray
plt.scatter(pretrained_coords[:, 0], pretrained_coords[:, 1], alpha=0.5, color="green", label="Pretrained (GloVe)", s=20)
plt.scatter(custom_coords[:, 0], custom_coords[:, 1], alpha=0.5, color="grey", label="Custom (A-La-Carte)", s=20)

# Plot each group with color
for i, group in enumerate(word_groups):
    color = group_colors[i % len(group_colors)]
    for w in group:
        if w in token_to_2d:
            c = token_to_2d[w]
            plt.scatter(c[0], c[1], color=color, s=40) 
            plt.text(c[0], c[1], w, fontsize=10, color=color, weight='bold')

# Draw lines between gender-paired words
for i, pair_group in enumerate(gender_pairs):
    color = group_colors[i % len(group_colors)]
    for w1, w2 in pair_group:
        if w1 in token_to_2d and w2 in token_to_2d:
            c1, c2 = token_to_2d[w1], token_to_2d[w2]
            plt.plot([c1[0], c2[0]], [c1[1], c2[1]], color=color, linestyle='--', linewidth=1)

plt.title("2D PCA projection of token embeddings with gender-paired distances")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend()
plt.show()

# %% [markdown]
# ## Extra: why is A-La-Carte less informative?

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict, Counter
import seaborn as sns

def analyze_oov_tokens(train_corpus, embedding_model, window_size=5):
    """
    Comprehensive analysis of OOV tokens in training corpus to understand
    why A-La-Carte embeddings might be concentrated/uninformative.
    
    Parameters:
    -----------
    train_corpus : list of lists
        Training corpus as list of tokenized documents
    embedding_model : dict
        Pre-trained embedding model (e.g., GloVe)
    window_size : int
        Context window size used in A-La-Carte
    """
    
    # Identify OOV tokens
    oov_tokens = set()
    all_tokens = []
    
    for doc in train_corpus:
        for token in doc:
            all_tokens.append(token)
            if token not in embedding_model:
                oov_tokens.add(token)
    
    print(f"Total tokens in corpus: {len(all_tokens)}")
    print(f"Unique tokens: {len(set(all_tokens))}")
    print(f"OOV tokens: {len(oov_tokens)}")
    print(f"OOV rate: {len(oov_tokens) / len(set(all_tokens)) * 100:.2f}%")
    print(f"OOV token occurrences: {sum(1 for t in all_tokens if t in oov_tokens)}")
    print(f"OOV occurrence rate: {sum(1 for t in all_tokens if t in oov_tokens) / len(all_tokens) * 100:.2f}%\n")
    
    # Metrics to collect
    oov_contexts = defaultdict(list)  # OOV token -> list of contexts (lists of in-vocab tokens)
    oov_per_context = []  # Number of OOV tokens per context window
    in_vocab_per_context = []  # Number of in-vocab tokens per context window
    oov_frequencies = Counter()  # Frequency of each OOV token
    context_diversity = {}  # OOV token -> unique contexts
    oov_distances = []  # Distances between OOVs in same context
    
    # Analyze contexts for each OOV occurrence
    for doc in train_corpus:
        for i, token in enumerate(doc):
            if token in oov_tokens:
                oov_frequencies[token] += 1
                
                # Extract context window
                start = max(0, i - window_size)
                end = min(len(doc), i + window_size + 1)
                context = doc[start:i] + doc[i+1:end]
                
                # Get absolute positions of tokens in context
                context_positions = list(range(start, i)) + list(range(i+1, end))
                
                # Separate in-vocab and OOV tokens in context
                in_vocab_context = [t for t in context if t in embedding_model]
                oov_in_context = [t for t in context if t not in embedding_model]
                
                # Calculate distances between OOVs in this context
                oov_positions = [pos for pos, t in zip(context_positions, context) if t not in embedding_model]
                if len(oov_positions) > 1:
                    # Calculate pairwise distances
                    for j in range(len(oov_positions)):
                        for k in range(j+1, len(oov_positions)):
                            distance = abs(oov_positions[k] - oov_positions[j])
                            oov_distances.append(distance)
                
                oov_contexts[token].append(in_vocab_context)
                oov_per_context.append(len(oov_in_context))
                in_vocab_per_context.append(len(in_vocab_context))
    
    # Calculate context diversity for each OOV
    for oov_token, contexts in oov_contexts.items():
        # Convert contexts to tuples for hashing
        unique_contexts = set(tuple(sorted(ctx)) for ctx in contexts)
        context_diversity[oov_token] = len(unique_contexts)
    
    # Create comprehensive visualizations
    fig = plt.figure(figsize=(20, 16))
    
    # 1. OOV frequency distribution
    ax1 = plt.subplot(4, 3, 1)
    freq_values = list(oov_frequencies.values())
    ax1.hist(freq_values, bins=50, edgecolor='black', alpha=0.7)
    ax1.set_xlabel('Frequency')
    ax1.set_ylabel('Number of OOV tokens')
    ax1.set_title('OOV Token Frequency Distribution')
    ax1.set_yscale('log')
    ax1.grid(True, alpha=0.3)
    
    # 2. In-vocab tokens per context distribution
    ax2 = plt.subplot(4, 3, 2)
    ax2.hist(in_vocab_per_context, bins=range(0, max(in_vocab_per_context)+2), 
             edgecolor='black', alpha=0.7, color='green')
    ax2.set_xlabel('Number of in-vocab tokens')
    ax2.set_ylabel('Frequency')
    ax2.set_title(f'In-Vocab Tokens per Context\n(Mean: {np.mean(in_vocab_per_context):.2f})')
    ax2.grid(True, alpha=0.3)
    
    # 3. OOV tokens per context distribution
    ax3 = plt.subplot(4, 3, 3)
    ax3.hist(oov_per_context, bins=range(0, max(oov_per_context)+2), 
             edgecolor='black', alpha=0.7, color='red')
    ax3.set_xlabel('Number of OOV tokens')
    ax3.set_ylabel('Frequency')
    ax3.set_title(f'OOV Tokens per Context\n(Mean: {np.mean(oov_per_context):.2f})')
    ax3.grid(True, alpha=0.3)
    
    # 4. Context diversity vs frequency
    ax4 = plt.subplot(4, 3, 4)
    freqs = [oov_frequencies[token] for token in context_diversity.keys()]
    diversities = list(context_diversity.values())
    ax4.scatter(freqs, diversities, alpha=0.5)
    ax4.set_xlabel('OOV Token Frequency')
    ax4.set_ylabel('Number of Unique Contexts')
    ax4.set_title('Context Diversity vs Frequency')
    ax4.set_xscale('log')
    ax4.grid(True, alpha=0.3)
    
    # 5. Context diversity distribution
    ax5 = plt.subplot(4, 3, 5)
    ax5.hist(diversities, bins=50, edgecolor='black', alpha=0.7, color='purple')
    ax5.set_xlabel('Number of Unique Contexts')
    ax5.set_ylabel('Number of OOV tokens')
    ax5.set_title('Context Diversity Distribution')
    ax5.grid(True, alpha=0.3)
    
    # 6. Diversity ratio (unique contexts / total occurrences)
    ax6 = plt.subplot(4, 3, 6)
    diversity_ratios = [context_diversity[token] / oov_frequencies[token] 
                       for token in context_diversity.keys()]
    ax6.hist(diversity_ratios, bins=50, edgecolor='black', alpha=0.7, color='orange')
    ax6.set_xlabel('Diversity Ratio')
    ax6.set_ylabel('Number of OOV tokens')
    ax6.set_title(f'Context Diversity Ratio\n(unique_contexts / frequency)\nMean: {np.mean(diversity_ratios):.3f}')
    ax6.grid(True, alpha=0.3)
    
    # 7. Cumulative distribution of in-vocab context sizes
    ax7 = plt.subplot(4, 3, 7)
    sorted_in_vocab = np.sort(in_vocab_per_context)
    cumulative = np.arange(1, len(sorted_in_vocab) + 1) / len(sorted_in_vocab)
    ax7.plot(sorted_in_vocab, cumulative, linewidth=2)
    ax7.set_xlabel('Number of in-vocab tokens')
    ax7.set_ylabel('Cumulative Probability')
    ax7.set_title('CDF: In-Vocab Tokens per Context')
    ax7.grid(True, alpha=0.3)
    ax7.axvline(np.median(in_vocab_per_context), color='red', 
                linestyle='--', label=f'Median: {np.median(in_vocab_per_context):.1f}')
    ax7.legend()
    
    # 8. Box plot: in-vocab vs OOV tokens per context
    ax8 = plt.subplot(4, 3, 8)
    box_data = [in_vocab_per_context, oov_per_context]
    bp = ax8.boxplot(box_data, labels=['In-Vocab', 'OOV'], patch_artist=True)
    bp['boxes'][0].set_facecolor('green')
    bp['boxes'][1].set_facecolor('red')
    ax8.set_ylabel('Number of tokens')
    ax8.set_title('Context Composition')
    ax8.grid(True, alpha=0.3, axis='y')
    
    # 9. OOV clustering analysis
    ax9 = plt.subplot(4, 3, 9)
    # Analyze OOV co-occurrence: when there ARE OOVs in context, how many?
    oov_present_contexts = [count for count in oov_per_context if count > 0]
    
    if oov_present_contexts:
        categories = ['No OOVs\nin Context', 'Has OOVs\nin Context']
        no_oov_contexts = len(oov_per_context) - len(oov_present_contexts)
        counts = [no_oov_contexts, len(oov_present_contexts)]
        colors = ['green', 'darkred']
        
        bars = ax9.bar(categories, counts, color=colors, edgecolor='black', alpha=0.7)
        ax9.set_ylabel('Number of OOV Occurrences')
        ax9.set_title(f'OOV Clustering in Contexts\n(Avg OOVs when present: {np.mean(oov_present_contexts):.2f})')
        ax9.grid(True, alpha=0.3, axis='y')
        
        for i, (cat, count) in enumerate(zip(categories, counts)):
            percentage = count / len(oov_per_context) * 100
            ax9.text(i, count, f'{percentage:.1f}%', ha='center', va='bottom', fontweight='bold')
    else:
        ax9.text(0.5, 0.5, 'No OOVs in contexts', ha='center', va='center', transform=ax9.transAxes)
    
    # 10. Distribution of OOV count per context (when OOVs are present)
    ax10 = plt.subplot(4, 3, 10)
    if oov_present_contexts:
        max_oov = max(oov_present_contexts)
        bins = range(1, max_oov + 2)  # Start from 1 since these are contexts WITH OOVs
        ax10.hist(oov_present_contexts, bins=bins, edgecolor='black', alpha=0.7, color='darkred')
        ax10.set_xlabel('Number of OOVs in Context')
        ax10.set_ylabel('Frequency')
        ax10.set_title(f'OOV Count Distribution (when present)\nMedian: {np.median(oov_present_contexts):.1f}, Max: {max_oov}')
        ax10.grid(True, alpha=0.3)
        ax10.axvline(np.mean(oov_present_contexts), color='blue', linestyle='--', 
                     linewidth=2, label=f'Mean: {np.mean(oov_present_contexts):.2f}')
        ax10.legend()
    else:
        ax10.text(0.5, 0.5, 'No contexts with multiple OOVs', ha='center', va='center', transform=ax10.transAxes)
    
    # 11. OOV distance distribution (when multiple OOVs in same context)
    ax11 = plt.subplot(4, 3, 11)
    if oov_distances:
        max_distance = min(max(oov_distances), 2 * window_size)  # Cap at max possible distance
        bins = range(1, max_distance + 2)
        ax11.hist(oov_distances, bins=bins, edgecolor='black', alpha=0.7, color='purple')
        ax11.set_xlabel('Distance Between OOVs (tokens)')
        ax11.set_ylabel('Frequency')
        ax11.set_title(f'Inter-OOV Distance Distribution\nMean: {np.mean(oov_distances):.2f}, Median: {np.median(oov_distances):.1f}')
        ax11.grid(True, alpha=0.3)
        ax11.axvline(window_size, color='red', linestyle='--', 
                     linewidth=2, label=f'Window size: {window_size}')
        ax11.legend()
    else:
        ax11.text(0.5, 0.5, 'No multiple OOVs in same context', ha='center', va='center', transform=ax11.transAxes)
    
    # 12. Distance vs OOV count scatter
    ax12 = plt.subplot(4, 3, 12)
    if oov_distances:
        # For each context with OOVs, compute average distance
        context_oov_counts = []
        context_avg_distances = []
        
        # Re-analyze to get per-context statistics
        for doc in train_corpus:
            for i, token in enumerate(doc):
                if token in oov_tokens:
                    start = max(0, i - window_size)
                    end = min(len(doc), i + window_size + 1)
                    context = doc[start:i] + doc[i+1:end]
                    context_positions = list(range(start, i)) + list(range(i+1, end))
                    
                    oov_positions = [pos for pos, t in zip(context_positions, context) if t not in embedding_model]
                    if len(oov_positions) > 1:
                        distances_in_context = []
                        for j in range(len(oov_positions)):
                            for k in range(j+1, len(oov_positions)):
                                distances_in_context.append(abs(oov_positions[k] - oov_positions[j]))
                        context_oov_counts.append(len(oov_positions))
                        context_avg_distances.append(np.mean(distances_in_context))
        
        if context_avg_distances:
            ax12.scatter(context_oov_counts, context_avg_distances, alpha=0.5, s=50)
            ax12.set_xlabel('Number of OOVs in Context')
            ax12.set_ylabel('Average Distance Between OOVs')
            ax12.set_title('OOV Density vs Spacing')
            ax12.grid(True, alpha=0.3)
            ax12.axhline(window_size, color='red', linestyle='--', alpha=0.5, label=f'Window size: {window_size}')
            ax12.legend()
        else:
            ax12.text(0.5, 0.5, 'Insufficient data', ha='center', va='center', transform=ax12.transAxes)
    else:
        ax12.text(0.5, 0.5, 'No multiple OOVs in same context', ha='center', va='center', transform=ax12.transAxes)
    
    plt.tight_layout()
    plt.show()
    
    # Print detailed statistics
    print("\n" + "="*80)
    print("DETAILED STATISTICS")
    print("="*80)
    
    print("\n1. CONTEXT SIZE STATISTICS:")
    print(f"   Average in-vocab tokens per context: {np.mean(in_vocab_per_context):.2f}")
    print(f"   Median in-vocab tokens per context: {np.median(in_vocab_per_context):.2f}")
    print(f"   Std dev in-vocab tokens per context: {np.std(in_vocab_per_context):.2f}")
    print(f"   Average OOV tokens per context: {np.mean(oov_per_context):.2f}")
    print(f"   Median OOV tokens per context: {np.median(oov_per_context):.2f}")
    
    print("\n2. CONTEXT QUALITY:")
    zero_context = sum(1 for count in in_vocab_per_context if count == 0)
    low_context = sum(1 for count in in_vocab_per_context if 0 < count < 3)
    print(f"   OOV occurrences with ZERO in-vocab context: {zero_context} ({zero_context/len(in_vocab_per_context)*100:.2f}%)")
    print(f"   OOV occurrences with 1-2 in-vocab tokens: {low_context} ({low_context/len(in_vocab_per_context)*100:.2f}%)")
    print(f"   OOV occurrences with 3+ in-vocab tokens: {len(in_vocab_per_context)-zero_context-low_context}")
    
    print("\n3. OOV CO-OCCURRENCE (CLUSTERING):")
    oov_present_contexts = [count for count in oov_per_context if count > 0]
    contexts_with_oov = len(oov_present_contexts)
    contexts_without_oov = len(oov_per_context) - contexts_with_oov
    print(f"   OOV occurrences with NO other OOVs in context: {contexts_without_oov} ({contexts_without_oov/len(oov_per_context)*100:.2f}%)")
    print(f"   OOV occurrences with other OOVs in context: {contexts_with_oov} ({contexts_with_oov/len(oov_per_context)*100:.2f}%)")
    if oov_present_contexts:
        print(f"   Average OOVs per context (when present): {np.mean(oov_present_contexts):.2f}")
        print(f"   Median OOVs per context (when present): {np.median(oov_present_contexts):.2f}")
        print(f"   Max OOVs in a single context: {max(oov_present_contexts)}")
        print(f"   Std dev OOVs per context (when present): {np.std(oov_present_contexts):.2f}")
    
    print("\n4. OOV SPATIAL DISTRIBUTION:")
    if oov_distances:
        print(f"   Total OOV pairs analyzed: {len(oov_distances)}")
        print(f"   Average distance between OOVs: {np.mean(oov_distances):.2f} tokens")
        print(f"   Median distance between OOVs: {np.median(oov_distances):.2f} tokens")
        print(f"   Min distance: {min(oov_distances)}, Max distance: {max(oov_distances)}")
        print(f"   Std dev of distances: {np.std(oov_distances):.2f}")
        print(f"   Window size for reference: {window_size} tokens")
        
        # Calculate percentage of OOVs very close together
        close_oovs = sum(1 for d in oov_distances if d <= 2)
        distant_oovs = sum(1 for d in oov_distances if d >= window_size)
        print(f"   OOV pairs within 2 tokens: {close_oovs} ({close_oovs/len(oov_distances)*100:.2f}%)")
        print(f"   OOV pairs >= window size apart: {distant_oovs} ({distant_oovs/len(oov_distances)*100:.2f}%)")
    else:
        print("   No multiple OOVs found in same context window")
    
    print("\n5. CONTEXT DIVERSITY:")
    print(f"   Average unique contexts per OOV: {np.mean(diversities):.2f}")
    print(f"   Median unique contexts per OOV: {np.median(diversities):.2f}")
    print(f"   Average diversity ratio: {np.mean(diversity_ratios):.3f}")
    print(f"   Median diversity ratio: {np.median(diversity_ratios):.3f}")
    
    print("\n6. OOV FREQUENCY STATISTICS:")
    print(f"   Average OOV token frequency: {np.mean(freq_values):.2f}")
    print(f"   Median OOV token frequency: {np.median(freq_values):.2f}")
    print(f"   OOVs appearing only once: {sum(1 for f in freq_values if f == 1)} ({sum(1 for f in freq_values if f == 1)/len(freq_values)*100:.2f}%)")
    print(f"   OOVs appearing 2-5 times: {sum(1 for f in freq_values if 2 <= f <= 5)}")
    print(f"   OOVs appearing 6+ times: {sum(1 for f in freq_values if f > 5)}")
    
    print("\n7. POTENTIAL ISSUES FOR A-LA-CARTE:")
    if np.mean(in_vocab_per_context) < 3:
        print("   ⚠️  LOW CONTEXT: Average in-vocab context size is very low!")
        print("      -> A-La-Carte has few tokens to average, leading to noisy embeddings")
    
    if zero_context / len(in_vocab_per_context) > 0.1:
        print("   ⚠️  ZERO CONTEXT: >10% of OOV occurrences have no in-vocab context!")
        print("      -> These will produce zero or near-zero embeddings")
    
    if np.mean(diversity_ratios) < 0.3:
        print("   ⚠️  LOW DIVERSITY: OOVs appear in very similar contexts!")
        print("      -> All embeddings will be similar, causing concentration")
    
    if contexts_with_oov / len(oov_per_context) > 0.5:
        oov_present_contexts = [count for count in oov_per_context if count > 0]
        avg_when_present = np.mean(oov_present_contexts) if oov_present_contexts else 0
        print(f"   ⚠️  HIGH OOV CLUSTERING: {contexts_with_oov/len(oov_per_context)*100:.1f}% of OOVs have other OOVs in context!")
        print(f"      -> Average {avg_when_present:.2f} OOVs per context when present")
        print("      -> OOVs learn from each other's (uninitialized) embeddings")
        print("      -> Results in similar, concentrated embeddings for all OOVs")
    
    if np.mean(diversity_ratios) < 0.5 and contexts_with_oov / len(oov_per_context) > 0.5:
        print("   🚨 CRITICAL: LOW DIVERSITY + HIGH OOV CLUSTERING!")
        print("      -> Same OOVs co-occur repeatedly in similar contexts")
        print("      -> A-La-Carte will produce nearly identical embeddings")
        print("      -> This explains the observed concentration phenomenon")
    
    print("\n" + "="*80)
    
    return {
        'oov_tokens': oov_tokens,
        'oov_frequencies': oov_frequencies,
        'in_vocab_per_context': in_vocab_per_context,
        'oov_per_context': oov_per_context,
        'oov_present_contexts': oov_present_contexts if oov_present_contexts else [],
        'context_diversity': context_diversity,
        'diversity_ratios': diversity_ratios
    }


# Example usage:
results = analyze_oov_tokens(train_corpus, embedding_model, window_size=WINDOW_SIZE)
# Out:
# Total tokens in corpus: 77636
# Unique tokens: 9116
# OOV tokens: 930
# OOV rate: 10.20%
# OOV token occurrences: 1262
# OOV occurrence rate: 1.63%
# /var/folders/n9/r8x6svc56fjb_2b7zb4tztr80000gn/T/ipykernel_35273/3400263671.py:159: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax8.boxplot(box_data, labels=['In-Vocab', 'OOV'], patch_artist=True)
# ...
# DETAILED STATISTICS
# ...
#
# 1. CONTEXT SIZE STATISTICS:
#    Average in-vocab tokens per context: 29.62
#    Median in-vocab tokens per context: 30.00
#    Std dev in-vocab tokens per context: 14.01
#    Average OOV tokens per context: 1.12
#    Median OOV tokens per context: 1.00
#
# 2. CONTEXT QUALITY:
#    OOV occurrences with ZERO in-vocab context: 0 (0.00%)
#    OOV occurrences with 1-2 in-vocab tokens: 3 (0.24%)
#    OOV occurrences with 3+ in-vocab tokens: 1259
#
# 3. OOV CO-OCCURRENCE (CLUSTERING):
# ...

# %% [markdown]
# # [Task 4 - 1.0 points] Model definition
#
# You are now tasked to define your sexism classifier.

# %% [markdown]
# ### Instructions
#
# * **Baseline**: implement a Bidirectional LSTM with a Dense layer on top.
#
# * **Stacked**: add an additional Bidirectional LSTM layer to the Baseline model.
#
# **Note**: You are **free** to experiment with hyper-parameters.

# %%
NUM_CLASSES = len(label_mapping.keys())

# NOTE: la struttura potrebbe essere too much ma visto che con ipcv ci eravamo trovati "bene" a testarla l'ho riproposta
hyperparams_models = {
    "baseline": {
        "model": {
            "lstm_units": 64,
            "dense_units": 32,
            "dropout_rate": 0.3,   
        },
        "train": {}
    },
    "stacked": {
        "model": {
            "lstm_units_1": 64,
            "lstm_units_2": 32,
            "dense_units": 32,
            "dropout_rate_1": 0.3,
            "dropout_rate_2": 0.3,
        },
        "train": {}
    }
}

# %% [markdown]
# ### Token to embedding mapping
#
# You can follow two approaches for encoding tokens in your classifier.

# %% [markdown]
# ### Work directly with embeddings
#
# - Compute the embedding of each input token
# - Feed the mini-batches of shape ``(batch_size, # tokens, embedding_dim)`` to your model

# %% [markdown]
# ### Work with Embedding layer
#
# - Encode input tokens to token ids
# - Define a Embedding layer as the first layer of your model
# - Compute the embedding matrix of all known tokens (i.e., tokens in your vocabulary)
# - Initialize the Embedding layer with the computed embedding matrix
# - You are **free** to set the Embedding layer trainable or not

# %%
# NOTE: For coherency, we want to handle OOV tokens in test/val as we did during training, instead of giving them a random encoding. To maintain test/val independence, we implemented a wrapper that applies A La Carte per-batch at inference time to provide more meaningful embeddings. 
# NOTE: Following Khodak et al. (2018), we compute OOV embeddings using only context words with known embeddings, excluding other OOVs to avoid noise propagation and maintain consistency with the transformation matrix training.

class ALaCarteEmbedding(Layer):
    """
    Custom Embedding layer that handles OOV tokens using A-La-Carte transformation.
    
    During training: uses static (frozen) embeddings from the embedding matrix.
    During inference: dynamically computes OOV embeddings from their local context.
    
    NOTE: Embeddings are always frozen (non-trainable) to maintain consistency
    with the A-La-Carte methodology and the space in which the transformation matrix
    was learned.
    
    Reference:
    Khodak, M., Saunshi, N., & Liang, P. (2018).
    "A La Carte Embedding: Cheap but Effective Induction of Semantic Feature Vectors."
    ACL 2018.
    """
    
    def __init__(
        self,
        vocab_size: int,
        embedding_dim: int,
        embedding_matrix: np.ndarray,
        transform_matrix: np.ndarray,
        oov_idx: int,
        mask_zero: bool = True,
        **kwargs
    ):
        """
        Initialize the A-La-Carte Embedding layer.
                
        :param vocab_size: size of the vocabulary
        :param embedding_dim: dimension of embeddings
        :param embedding_matrix: pre-computed embedding matrix (vocab_size x embedding_dim)
        :param transform_matrix: A-La-Carte transformation matrix (embedding_dim x embedding_dim)
        :param oov_idx: index of the <OOV> token in the vocabulary
        :param mask_zero: whether to mask padding tokens (index 0)
        """
        super(ALaCarteEmbedding, self).__init__(**kwargs)
        
        self.vocab_size = vocab_size
        self.embedding_dim = embedding_dim
        self.mask_zero = mask_zero
        self.oov_idx = oov_idx
        
        # Static embedding matrix ==> always frozen 
        # This ensures consistency with the A-La-Carte methodology
        self.embedding = tf.keras.layers.Embedding(
            input_dim=vocab_size,
            output_dim=embedding_dim,
            weights=[embedding_matrix],
            mask_zero=mask_zero,
            trainable=False,  # NOTE: to be consistent with alacarte transfom matrix ("A")
            name='frozen_embedding'
        )
        
        # A-La-Carte transformation matrix
        self.transform_matrix = tf.constant(transform_matrix, dtype=tf.float32)
        
    def call(self, inputs, training=None):
        """
        Forward pass with dynamic OOV handling during inference.
        
        During training: returns static (frozen) embeddings.
        During inference: computes contextual embeddings for OOV tokens.
        
        :param inputs: tensor of shape (batch_size, seq_len) containing token indices
        :param training: boolean flag indicating training vs inference mode
        :return: tensor of shape (batch_size, seq_len, embedding_dim)
        """
        # Get base embeddings from the static embedding matrix
        embedded = self.embedding(inputs)  # (batch_size, #tokens, embedding_dim)
        
        if not training:
            # During inference, compute contextual embeddings for OOV tokens
            embedded = self._replace_oov_with_context(inputs, embedded)
        
        return embedded
    
    def _replace_oov_with_context(self, inputs, embedded):
        """
        Replaces OOV embeddings with embeddings computed from local context.
        
        For each OOV token in each sequence:
        1. Extract context words from the same sequence (excluding the OOV position)
        2. Filter context to keep only known words (exclude padding and other OOVs)
        3. If valid context exists, compute average context embedding
        4. Apply A-La-Carte transformation to get the OOV embedding
        5. If no valid context exists, keep the frozen random OOV embedding
        
        NOTE: We explicitly exclude other OOV tokens from the context because:
        - The transformation matrix was trained on contexts of known words only
        - Including random OOV embeddings would introduce noise
        - This follows the original A-La-Carte methodology
        
        :param inputs: token indices (batch_size, seq_len)
        :param embedded: current embeddings (batch_size, seq_len, embedding_dim)
        :return: updated embeddings with computed OOV embeddings
        """
        batch_size = tf.shape(inputs)[0]
        seq_len = tf.shape(inputs)[1]
        
        # Find all OOV positions in the batch
        oov_mask = tf.equal(inputs, self.oov_idx)
        
        # Early return if no OOVs in this batch
        if not tf.reduce_any(oov_mask):
            return embedded
        
        # Process each sequence independently to maintain test/val independence
        for i in tf.range(batch_size):
            sequence = inputs[i]  # (seq_len,)
            
            # Find OOV positions in this specific sequence
            oov_positions = tf.where(tf.equal(sequence, self.oov_idx))
            
            if tf.size(oov_positions) == 0:
                continue
            
            # For each OOV token in this sequence
            for pos_tensor in oov_positions:
                pos = pos_tensor[0]
                
                # Build context indices: all positions except the current OOV position
                context_indices = tf.concat([
                    tf.range(0, pos),           # tokens before OOV
                    tf.range(pos + 1, seq_len)  # tokens after OOV
                ], axis=0)
                
                # Get context tokens
                context_tokens = tf.gather(sequence, context_indices)
                
                # Filter context: keep only valid tokens
                # NOTE: We exclude both padding (0) and ALL other OOVs
                valid_mask = tf.logical_and(
                    tf.not_equal(context_tokens, 0),           # not padding
                    tf.not_equal(context_tokens, self.oov_idx) # not OOV
                )
                valid_context_indices = tf.boolean_mask(context_indices, valid_mask)
                
                # If there's at least one known word in the context, compute OOV embedding
                if tf.size(valid_context_indices) > 0:
                    # Get embeddings of valid context tokens
                    context_embeddings = tf.gather(embedded[i], valid_context_indices)
                    
                    # Compute average context embedding
                    avg_context = tf.reduce_mean(context_embeddings, axis=0)
                    
                    # Apply A-La-Carte transformation: A @ avg_context
                    alacarte_emb = tf.linalg.matvec(
                        self.transform_matrix,
                        avg_context
                    )
                    
                    # Update the OOV embedding in the embedded tensor
                    indices = [[i, pos]]
                    embedded = tf.tensor_scatter_nd_update(
                        embedded,
                        indices,
                        [alacarte_emb]
                    )
                # If no valid context (only OOVs/padding), keep the frozen random embedding
        
        return embedded
    
    def compute_mask(self, inputs, mask=None):
        """
        Compute mask for the layer to handle variable-length sequences.
        
        :param inputs: token indices
        :param mask: existing mask (if any)
        :return: boolean mask where True indicates valid (non-padding) positions
        """
        if self.mask_zero:
            return tf.not_equal(inputs, 0)
        return mask

# %%
models = {
    "baseline" : Sequential([
                    Embedding( # TODO: put alacarte embedding
                        input_dim=vocab_size, 
                        output_dim=EMBEDDING_DIMENSION,
                        weights=[embedding_matrix],
                        mask_zero=True,
                        name='encoder_embedding'
                    ),
                    Bidirectional(LSTM(
                        units=hyperparams_models["baseline"]["model"]["lstm_units"],
                        return_sequences=False
                    )),
                    Dropout(hyperparams_models["baseline"]["model"]["dropout_rate"]),
                    Dense( # NOTE: is this necesary ?
                        units=hyperparams_models["baseline"]["model"]["dense_units"],
                        activation='relu'
                    ),
                    Dense(units=NUM_CLASSES, activation='softmax')
                ], name="baseline_bidirectional_lstm"),
    
    
    "stacked" : Sequential([
                    Embedding( # TODO: put alacarte ebedding
                        input_dim=vocab_size,
                        output_dim=EMBEDDING_DIMENSION,
                        weights=[embedding_matrix],
                        mask_zero=True,
                        name='encoder_embedding'
                    ),
                    Bidirectional(LSTM(
                        units=hyperparams_models["stacked"]["model"]["lstm_units_1"],
                        return_sequences=True  # NOTE: return sequences for stacking
                    )),
                    Dropout(hyperparams_models["stacked"]["model"]["dropout_rate_1"]),
                    Bidirectional(LSTM(
                        units=hyperparams_models["stacked"]["model"]["lstm_units_2"],
                        return_sequences=False
                    )),
                    Dropout(hyperparams_models["stacked"]["model"]["dropout_rate_2"]),
                    Dense( # NOTE: is this necesary ?
                        units=hyperparams_models["stacked"]["model"]["dense_units"],
                        activation='relu'
                    ),
                    Dense(units=NUM_CLASSES, activation='softmax')
                ], name="stacked_bidirectional_lstm")
}

# %% [markdown]
# # [Task 5 - 1.0 points] Training and Evaluation
#
# You are now tasked to train and evaluate the Baseline and Stacked models.

# %% [markdown]
# ### Instructions
#
# * Pick **at least** three seeds for robust estimation.
# * Train **all** models on the train set.
# * Evaluate **all** models on the validation and test sets.
# * Compute macro F1-score, precision, and recall metrics on the validation set.
# * Report average and standard deviation measures over seeds for each metric.
# * Pick the **best** performing model according to the observed validation set performance (use macro F1-score).

# %% [markdown]
# # [Task 6 - 1.0 points] Transformers
#
# In this section, you will use a transformer model specifically trained for hate speech detection, namely [Twitter-roBERTa-base for Hate Speech Detection](https://huggingface.co/cardiffnlp/twitter-roberta-base-hate).

# %% [markdown]
# ### Relevant Material
# - Tutorial 3

# %% [markdown]
# ### Instructions
# - **Load the Tokenizer and Model**
#
# - **Preprocess the Dataset**:
#    You will need to preprocess your dataset to prepare it for input into the model. Tokenize your text data using the appropriate tokenizer and ensure it is formatted correctly.
#
# - **Train the Model**:
#    Use the `Trainer` to train the model on your training data.
#
# - **Evaluate the Model on the Test Set** using the same metrics used for LSTM-based models.

# %% [markdown]
# # [Task 7 - 0.5 points] Error Analysis
#
# After evaluating the model, perform a brief error analysis on the **test set**:

# %% [markdown]
# ### Instructions
#
#  - Review the results and identify common errors.
#
#  - Summarize your findings regarding the errors and their impact on performance (e.g. but not limited to Out-of-Vocabulary (OOV) words, data imbalance, and performance differences between the custom model and the transformer...)
#  - Suggest possible solutions to address the identified errors.

# %% [markdown]
# # [Task 8 - 0.5 points] Report
#
# Wrap up your experiment in a short report (up to 2 pages).

# %% [markdown]
# ### Instructions
#
# * Use the NLP course report template.
# * Summarize each task in the report following the provided template.

# %% [markdown]
# ### Recommendations
#
# The report is **not a copy-paste** of graphs, tables, and command outputs.
#
# * Summarize classification performance in Table format.
# * **Do not** report command outputs or screenshots.
# * Report learning curves in Figure format.
# * The error analysis section should summarize your findings.

# %% [markdown]
# # Submission
#
# * **Submit** your report in PDF format.
# * **Submit** your python notebook.
# * Make sure your notebook is **well organized**, with no temporary code, commented sections, tests, etc...
# * You can upload **model weights** in a cloud repository and report the link in the report.

# %% [markdown]
# ## Bonus Points
# Bonus points are arbitrarily assigned based on significant contributions such as:
# - Outstanding error analysis
# - Masterclass code organization
# - Suitable extensions
#
# **Note**: bonus points are only assigned if all task points are attributed (i.e., 6/6).

# %% [markdown]
# **Possible Suggestions for Bonus Points:**
# - **Try other preprocessing strategies**: e.g., but not limited to, explore techniques tailored specifically for tweets or  methods that are common in social media text.
# - **Experiment with other custom architectures or models from HuggingFace**
# - **Explore Spanish tweets**: e.g., but not limited to, leverage multilingual models to process Spanish tweets and assess their performance compared to monolingual models.

# %% [markdown]
# # FAQ
#
# Please check this frequently asked questions before contacting us

# %% [markdown]
# ### Trainable Embeddings
#
# You are **free** to define a trainable or non-trainable Embedding layer to load the GloVe embeddings.

# %% [markdown]
# ### Model architecture
#
# You **should not** change the architecture of a model (i.e., its layers).
#
# However, you are **free** to play with their hyper-parameters.

# %% [markdown]
# ### Neural Libraries
#
# You are **free** to use any library of your choice to implement the networks (e.g., Keras, Tensorflow, PyTorch, JAX, etc...)

# %% [markdown]
# ### Robust Evaluation
#
# Each model is trained with at least 3 random seeds.
#
# Task 5 requires you to compute the average performance over the 3 seeds and its corresponding standard deviation.

# %% [markdown]
# ### Expected Results
#
# Task 2 leaderboard reports around 40-50 F1-score.
# However, note that they perform a hierarchical classification.
#
# That said, results around 30-40 F1-score are **expected** given the task's complexity.

# %% [markdown]
# ### Model Selection for Analysis
#
# To carry out the error analysis you are **free** to either
#
# * Pick examples or perform comparisons with an individual seed run model (e.g., Baseline seed 1337)
# * Perform ensembling via, for instance, majority voting to obtain a single model.

# %% [markdown]
# ### Error Analysis
#
# Some topics for discussion include:
#    * Precision/Recall curves.
#    * Confusion matrices.
#    * Specific misclassified samples.

# %% [markdown]
# # The End
#
# Feel free to reach out for questions/doubts!
